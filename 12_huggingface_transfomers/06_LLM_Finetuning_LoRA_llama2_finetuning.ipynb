# %%
# !nvidia-smi

# %%
# %pip install -U accelerate peft bitsandbytes transformers trl datasets fsspec

# %% [markdown]
# # [PEFT - Parameter-Efficient Fine-Tuning](https://github.com/huggingface/peft)
#
# - 딥러닝 모델의 크기가 커질수록 태스크별로 모든 파라미터를 조정하는 full-fine-tuning 방식은 자원 소모와 시간, 비용적인 측면에서 점점 힘들어 지고 있다.
#   - 예: 대규모 언어 모델(LLM)에서 full-fine-tuning 시 수십억 개에서 수천억 개의 파라미터를 업데이트해야 함.
# - 이를 해결하기 위해 PEFT(Parameter-Efficient Fine-Tuning) 방법이 주목받고 있다.
#   - PEFT는 다운스트림 작업의 성능을 유지하거나 향상시키면서 계산량과 모델 크기를 줄이는 것이 목표다.
#   - 예: LoRA(Low-Rank Adaptation), Adapter Tuning 같은 기술이 대표적인 PEFT 방식이다.
#
# ## 주요 기법
#
# 1. **어댑터 튜닝(Adapter Tuning)**
#     - 기존 사전학습 모델에 어댑터 레이어를 추가하고, 어댑터 레이어만 학습시키는 방식.
#     - 이를 통해 모델의 주요 파라미터를 수정하지 않으면서도 새로운 작업에 맞게 미세 조정할 수 있다.
#     - LoRA(Low-Rank Adaptation)이 대표적인 어댑터 튜닝 방식이다.
#
# 2. **프롬프트 튜닝(Prompt Tuning)**
#     - 모델의 입력 앞에 학습 가능한 프롬프트를 추가하여 해당 프롬프트만 학습하는 방식.
#     - 이를 통해 기존 모델의 파라미터를 수정하지 않고도 다양한 작업에 빠르게 적응할 수 있다.
#
# 3. **P-튜닝(P-Tuning)**
#     - 입력 시퀀스 전체에 학습 가능한 연속적인 프롬프트 벡터를 삽입하여 해당 벡터들만 학습하는 방식.
#     - 프롬프트 튜닝과 달리, P-튜닝은 입력의 다양한 위치에 프롬프트 벡터를 삽입하여 모델의 출력을 조정한다.

# %% [markdown]
# # [LoRA (Low-Rank Adaptation)](https://arxiv.org/abs/2106.09685)
# - LoRA는 모델 파라미터를 재구성해 더 적은 파라미터를 학습하여 GPU 메모리 사용량을 줄인다.
# - LoRA의 파라미터 재구성은 모델의 Parameter 행렬을 더 작은 2개의 행렬 곱으로 표현해 추가하여 전체 파라미터를 수정(학습) 하는 것이 아니라 더 작은 2개 행렬을 수정(학습)하는 것을 말한다.
#
# ![LoRA](figures/LoRA.png)

# %% [markdown]
# - 위의 그림을 보면 파란색이 사전학습 모델의 파라미터고 주황색이 재구성된 파라미터 이다.
# - 모델은 d차원의 입력 X와 `d x d` 차원의 파라미터 W를 곱해 최종적으로 d차원의 결과 h를 출력한다.
#     - 만약 d차원이 100이라면 파라미터는 100000 개의 파라미터를 가진다.
# - LoRA는 모델의 파라미터를 고정시키고 **d x r**인 행렬 A와 **r x d** 인 행렬 B를 추가하고 이 두 행렬을 곱해 d차원의 결과 h`를 출력한다.
# - 사전학습 모델의 파라미터가 출력한 h와 LoRA adapter가 출력한 h` 를 더해 최종 결과를 출력한다.
#     - **d x r**인 행렬 A와 **r x d** 행렬 B를 행렬곱을 하면 **d x d** 행렬이 되어 사전학습 모델의 파라미터의 출력과 같은 차원의 결과를 출력한다.
# - 행렬 A와 B의 r을 d보다 작은 값으로 설정하면 d x d 인 행렬 W 보다 훨씬 적은 파라미터로 학습시킬 수 있다.
# - Adaptor가 추가 되어 전체 모델의 파라미터는 조금 늘어난다. 하지만 학습 과정에서는 adpator만 학습하므로 gradient와 옵티마이저의 파라미터 양이 줄어들어 GPU 메모리를 적세 사용할 수있다.
#
# ### LoRA 설정
# - r: 행렬 A와 B를 만들때 r을 몇으로 할지 설정한다.
# - alpah: adaptor 파라미터의 결과를 기존 파라미터의 결과에 얼마나 반영할지를 결정하는 하이퍼파라미터.
#     - alpha/r 을 결과 d에 곱해 기존 파라미터의 결과와 더한다.
#         - alpha가 16이고 r이 8인 경우 행렬 A, B에 2(16/8)을 곱해 기존 파라미터에 더해준다.
#     - alpha가 커질 수록 새로게 학습한 파라미터의 중요성을 더 크게 고려한다.
# - 모델의 파라미터어 중 어디에 adaptor를 적용해 파라미터를 재구성할지 결정해야 한다.
#     - transformer의 self-attention layer는 query, key, value, feed-forward의 linear layer로 구성되있다. 이 중 특정 파라미터에만 LoRA를 적용할 수있고 전체에 적용할 수있다.

# %% [markdown]
# # SQuAD Dataset
# - The Stanford Question Answering Dataset. 스탠포드 대학에서 만든 10만개의 Question & Answer 쌍으로 구성된 데이터셋
# - Question과 Answer를 위한 context 문장이 주어지고 해당 Paragraph에있는 정보를 통대로 정답을 맞추는 데이터셋이다.
# - https://rajpurkar.github.io/SQuAD-explorer/
#
# # KorQuAD Dataset
# - Korean Question Answering Dataset (KorQuad v1.0)은 LG CNS에서 구축한 SQuAD 데이터셋의 한국어 버전.
# - KorQuAD 1.0의 전체 데이터는 1,560 개의 Wikipedia article에 대해 10,645건의 Context 문장과 66,181 개의 질의응답 쌍으로, Training set 60,407 개, validation set
# 5,774 개의 질의응답쌍으로 구성되어 있다.
# - 공식 사이트
#     - V1: https://korquad.github.io/category/1.0_KOR.html
#     - V2: https://korquad.github.io/
# - HuggingFace Dataset
#     - https://huggingface.co/datasets/KorQuAD/squad_kor_v1

# %%
from datasets import Dataset, load_dataset

ds = load_dataset("KorQuAD/squad_kor_v1", split="validation")
# Out:
# README.md:   0%|          | 0.00/6.29k [00:00<?, ?B/s]
# c:\Users\Playdata\miniconda3\envs\langchain\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Playdata\.cache\huggingface\hub\datasets--KorQuAD--squad_kor_v1. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# train-00000-of-00001.parquet:   0%|          | 0.00/11.6M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/60407 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/5774 [00:00<?, ? examples/s]

# %%
ds
# Out:
# Dataset({
#     features: ['id', 'title', 'context', 'question', 'answers'],
#     num_rows: 5774
# })

# %%
ds[100]['answers']["text"][0]
# Out:
# '순풍'

# %%
refined_dict = {}

for data in ds:
  question = data['question']
  answer = data["answers"]["text"][0]
  refined_dict[question] = answer

len(refined_dict)
# Out:
# 5764

# %%
refined_dict
"### Instruction: 임종석이 여의도 농민 폭력 시위를 주도한 혐의로 지명수배 된 날은? ### Response: 1989년 2월 15일"
"### Instruction: 임종석이 여의도 농민 폭력 시위를 주도한 혐의로 지명수배 된 날은? ### Response: "
# Out:
# {'임종석이 여의도 농민 폭력 시위를 주도한 혐의로 지명수배 된 날은?': '1989년 2월 15일',
#  '1989년 6월 30일 평양축전에 대표로 파견 된 인물은?': '임수경',
#  '임종석이 여의도 농민 폭력 시위를 주도한 혐의로 지명수배된 연도는?': '1989년',
#  '임종석을 검거한 장소는 경희대 내 어디인가?': '학생회관 건물 계단',
#  '임종석이 조사를 받은 뒤 인계된 곳은 어딘가?': '서울지방경찰청 공안분실',
#  '1989년 2월 15일 여의도 농민 폭력 시위를 주도한 혐의로 지명수배된 사람의 이름은?': '임종석',
#  '임종석이 1989년 2월 15일에 지명수배 받은 혐의는 어떤 시위를 주도했다는 것인가?': '여의도 농민 폭력 시위',
#  '정부의 헌법개정안 준비 과정에 대해서 청와대 비서실이 아니라 국무회의 중심으로 이뤄졌어야 했다고 지적한 원로 헌법학자는?': '허영',
#  "'행보가 비서 본연의 역할을 벗어난다', '장관들과 내각이 소외되고 대통령비서실의 권한이 너무 크다'는 의견이 제기된 대표적인 예는?": '10차 개헌안 발표',
#  '국무회의의 심의를 거쳐야 한다는 헌법 제 몇 조의 내용인가?': '제89조',
#  '법무부 장관을 제쳐놓고 민정수석이 개정안을 설명하는 게 이해가 안 된다고 지적한 경희대 석좌교수 이름은?': '허영',
#  '미국 군대 내 두번째로 높은 직위는 무엇인가?': '미국 육군 부참모 총장',
#  '로널드 레이건 정부 출범 당시 알렉산더 헤이그는 어떤 직책을 맡았는가?': '초대 국무장관직',
#  '알렉산더 헤이그는 어느 대통령의 밑에서 국무장관을 지냈는가?': '로널드 레이건 대통령',
#  '로널드 레이건 대통령 밑에서 일한 국무 장관은 누구인가?': '알렉산더 메이그스 헤이그 2세',
#  '미국 군대에서 두번째로 높은 직위는?': '미국 육군 부참모 총장',
#  '알렉산더 메이그스 헤이그의 생년월일은?': '1924년 12월 2일',
#  '알렉산더 헤이그가 로널드 레이건 대통령 밑에서 맡은 직책은 무엇이었나?': '국무장관',
#  '알렉산더 헤이그가 1984년 발간한 회고록의 제목은 무엇인가?': '경고:현실주의, 레이건과 외교 정책',
#  '알렉산더 헤이그와 1950년 5월 결혼한 상대의 이름은 무엇인가?': '퍼트리샤 앤토이넷 폭스',
#  '알렉산더 헤이그가 미국 육군사관학교로 임명받은 해는 언제인가?': '1944년',
#  '알렉산더 헤이그는 퍼트리샤 앤토이넷 폭스와 결혼해 몇 명의 자녀를 두었는가?': '3명',
#  '헤이그가 공부한 대학교는?': '노터데임 대학교',
#  '헤이그의 부인은 누구인가?': '퍼트리샤 앤토이넷 폭스',
#  '알렉산더 헤이그가 나온 대학교는?': '노터데임 대학교',
#  '육군사관학교에서 졸업한 헤이그가 제일 처음 소위로 발령받은 부대는 무엇이었나?': '정통 제병 연합부대',
#  '1950년 헤이그와 결혼한 여자의 이름은?': '퍼트리샤 앤토이넷 폭스',
#  '헤이그가 군에서 퇴역한 해는 언제인가?': '1979년',
#  '알렉산더 헤이그를 사성 장군과 육군 부참모로 진급시킨 대통령은 누구인가?': '닉슨 대통령',
#  '헤이그는 나토에서 얼마나 있었습니까?': '5년',
#  '헤이그가 군에서 퇴역한 년도는 몇년도입니까?': '1979년',
#  '제럴드 포드 대통령 시기 헤이그가 최고사령부의 최고 사령관으로 임명된 곳은 어디인가?': '미국 유럽 연합군',
#  '헤이그가 군대에서 퇴역한 년도는?': '1979년',
#  '퇴역 후 헤이그는 어느 회사의 대표가 되었나?': '미국 기술 주식 회사',
#  '알렉산더 헤이그는 레이건의 조언자들을 무엇이라고 묘사하였는가?': '외교 정책의 아마추어',
#  '헤이그가 사적생활을 하다가 정계로 돌아갔던 해는 언제인가?': '1988년',
#  '헤이그를 기용한 국제적 상담 회사의 이름은 무엇입니까?': 'Worldwide Associates Inc',
#  '헤이그가 정계로 돌아간 년도는 몇년도입니까?': '1988년',
#  '레이건 대통령의 조언자들을 헤이그는 무엇이라고 묘사하였나?': '외교 정책의 아마추어',
#  '헤이그가 정계로 다시 돌아간 년도는?': '1988년',
#  '하나님의 명령에 배를 만들고 가족과 짐승들을 배에 태워 홍수를 피한 사람은 누구인가?': '노아',
#  '노아의 방주에 대해 기록하고있는 복음서는 무엇인가?': '창세기',
#  '노아의 방주의 선체는 어떠한 나무로 만들었는가?': '고페르나무',
#  '노아는 누구의 명령에 따라 배를 만들고 가족과 동물들을 태웠는가?': '하나님',
#  '노아의 방주는 몇층으로 구성되어 있었는가?': '3층',
#  '노아의 방주에 안쪽에 발라 굳힌 것은?': '역청',
#  '1규빗을 미터법으로 환산하면 얼마인가?': '45~46cm',
#  '노아의 방주는 총 몇층으로 되어 있었는가?': '3층',
#  '노아의 방주를 만든 재질은?': '고페르나무(잣나무)',
#  '노아의 방주를 상징적 의미로 받아들이는 종교는 무엇인가?': '기독교',
#  '노아의 방주의 실존에 대한 의문이 제기되고 세계적 홍수가 없었다는 것이 밝혀지게된 이유는?': '역사학과 과학의 발달',
#  '역사학과 과학의 발달이 미비했을 때 전통 신학계에서는 어떠한 시작으로 노아의 방주를 역사적 사실로 기술하였는가?': '근본주의적',
#  '전통 신학계의 근본주의적 시작을 여전히 받아들여 노아의 방주를 역사적 사실로 인식하는 집단은?': '보수적 근본주의계열의 개신교',
#  '현대 대부분의 기독교에서는 노아의 방주를 어떤 의미로 받아들이는가?': '상징적 의미',
#  '현재도 노아의 방주를 역사적 사실로 받아들이는 집단은?': '보수적 근본주의계열의 개신교',
#  '노아의 방주의 실존에 대한 의문을 제기한 학문은?': '역사학과 과학',
#  '제칠일안식교에서 비롯된 의사과학의 한 종류인 유사지질학의 이름은 무엇인가?': '홍수지질학',
#  '극보수주의계열의 기독교이자 아직도 노아의 홍수가 있었다고 주장하는 곳은 어디인가?': '남침례교',
#  '고대사회에서 성경은 교리를 다루는 책일 뿐만 아니라 어떤 책으로도 권위가 상당했는가?': '역사책',
#  '역사학과 과학의 발달로 홍수지질학은 어떤 과학으로 남게 되었는가?': '유사과학',
#  '현대에 노아의 방주에 대학 근본주의적 해석은 어떻게 여겨지는가?': '비과학적인 해석',
#  '유사지질학인 홍수지질학이 근원은?': '제칠일안식교',
#  '유사지질학자들이 노아의 홍수를 증명하기 위해 성경 이외에 근거라고 주장한 것들은?': '이슬람교 경전이나 길가메쉬 서사시',
#  '노아의 방주가 역사적으로 실재했다는 주장은 무엇이 존재하지 않아 학계로부터 전혀 인정받지 못하고 있는가?': '증거',
#  '한국에서 홍수지질학적 주장들을 내어 놓고 있는 집단은?': '한국창조과학회',
#  '1955년 목재의 파편을 발견한 프랑스의 탐험가 이름은?': 'Fernand Navarra',
#  '2012년 중국에서 노아의 방주가 발견되었다는 보도를 한 방송사는 어디인가?': 'BTV',
#  '노아의 방주는 무엇으로 만들었기 때문에 현재까지 남아 있는 것이 불가능한가?': '목재',
#  '중국에서 2012년 발견되었다고 주장한 노아의 방주는 화석화가 진행되지 않은 무엇때문에 가짜임이 밝혀졌는가?': '나무',
#  '1955년 프랑스 탐험가가 발견한 목재파편은 스페인 연구소에서 몇 년 전 것이라고 밝혀졌는가?': '5000년 전',
#  '2012년 중국 BTV에서 노아의 방주가 발견되었다고 보도한 나라는?': '중국',
#  '현재의 생물다양성은 대략 몇 종 인가?': '870만',
#  '노아의 홍수가 실재한다면 진화적 종분화가 얼마 만에 이루어져야하는가?': '3-4천년',
#  '급작스러운 폭우로 담수와 염수가 섞일 경우 삼투압 변화로 폐사하는 생물류는?': '수생생물',
#  '가지고 있는 특성이 없어지는 것은 진화가 아니라는 창조과학회의 주장의 예시는?': '북극곰',
#  '만약 대홍수가 실재했다면 현생 지구의 생물다양성에 이르기 위해서는 종분화가 몇년 이내에 이루어졌어야 하는가?': '3-4천년',
#  '담수와 염수가 급작스럽게 섞일 경우 대부분의 수생생물이 폐사하는 원인은?': '급격한 삼투압 변화',
#  '노아 가족과 동물들이 노아의 방주에서 버틴 날짜는 총 몇일인가?': '375일',
#  '목재 선박의 배수량의 한계는 얼마인가?': '2000톤',
#  '노아의 방주가 안정적인 구조였다고 주장하는 집단은 어디인가?': '창조과학회',
#  '목재 선박은 강도상의 문제로 통상 길이 몇m가 한계인가?': '100m',
#  '노아의 방주 안정성을 실험하기 위한 연구가 있다고 주장하는 단체는?': '창조과학회',
#  '노아의 방주 안전성을 연구하는 주요 연구자의 직업은?': '초등학교 교사',
#  '목재로 만들어진 선박은 강도 상의 통상 길이 몇m가 한계인가?': '100m',
#  '목재 선박의 배수량 한계는?': '2000톤',
#  '1868년 게이오 4년 4월 11일 반류마루는 누구에게 양도되기로 약속되었는가?': '신정부 군',
#  '1868년 게이오 4년 4월 11일 신정부 군에게 양도되기로 한 반류마루를 기상 불량 등의 이유로 연기한 후 인도를 거부한 사람은 누구인가?': '에노모토 다케아키',
#  '1868년 게이오 4년 8월 19일 자정 반류마루가 탈출한 해역은 어디인가?': '시나가와',
#  '막부 해군이 정박하고 있던 시나가와 해역을 탈출한 시간은?': '자정',
#  '군함에 통합되어 실제로 쇼군이 엠퍼러에 첫 좌승한것은 대정봉환 이후 어디에 이송되었을 때인가?': '슨푸 번',
#  '1868년 당시 일본의 해군 부총재는?': '에노모토 다케아키',
#  '에노모토 해군인 반류마루가 주력함이 되었던 전쟁은?': '하코다테 전쟁',
#  '쇼군이 반류마루에 좌승한 것은?': '슨푸 번에 이송되었을 때',
#  '하코다테 전쟁 시 반류마루의 함장의 이름은 무엇인가?': '마쓰오카 바키치',
#  '반류마루가 미야코 만 해전에서 폭풍우를 만나 대기하고 있던 항구의 이름은 무엇인가?': '하치노헤',
#  '반류마루가 미야코 만 해전당시 폭풍우를 만나 요함과 헤어졌을 때에 만날 약속하여 하치노헤 항에서 대기한 날짜는 언제인가?': '1869년 메이지 2년 3월 25일',
#  '함장 마쓰오카 바키치는 배를 조정하는 명수로 로프 하나 손상되지 않았다고 말한 사람은?': '하야시 다다스',
#  '철갑선의 사정거리에 들어간 순간에 순풍이 불기 시작하여 추격을 뿌리치고 어디로 돌아올 수 있었는가?': '하코다테',
#  '마쓰오카 바키치함장의 능력과 지휘과 기록된 기록되어 남은 전쟁은?': '하코다테 전쟁',
#  '미야코 만 해전에서 아쓰오카 바키치 함장이 폭풍우를 만난 년도는?': '1869년',
#  '마쓰오카 비키치가 철갑선의 추격을 뿌리치고 하코다테로 돌아올 수 있었던 원인은?': '순풍',
#  '1869년 5월 11일 하코다테 해전에서 반류마루가 응전을 벌인 함대는?': '신정부 군 함대',
#  '1869년 5월 11일 하코다테 해전에서 반류마루가 신정부 군 함대와 응전을 벌일 때 원호를 받은 함대의 이름은 무엇인가?': '가이텐마루',
#  '1869년 5월 11일 하코다테 해전에서 반류마루가 작렬탄을 명중시켜 굉침시킨 군함의 이름은?': '초요마루',
#  '초요마루는 대폭발을 일으켜 몇분만에 굉침되었는가?': '2분',
#  '반류마루는 오후가 되면서 무엇이 소진되어 부득이 퇴함을 결정하였는가?': '탄약',
#  '반류마루 함장의 이름은?': '마쓰오카 바키치',
#  '신정부군의 손에 방화를 당한 함정은?': '반류마루',
#  '1869년 5월 11일 반류마루가 가이텐마루의 원호를 받으며 신정부군 함대와 응전을 벌인 해전은?': '하코다테 해전',
#  '철학이라는 용어 자체는 어디에서 유래 되었는가?': '고대 그리스어',
#  '오늘날 서양 철학은 2가지 주요한 전통을 지니고 있는데 분석철학과 나머지 한개는 무엇인가?': '대륙 철학',
#  "'철학'은 어디에서 유래한 용어인가?": '고대 그리스어',
#  '분석 철학과 대륙 철학이라는 두 가지 전통을 지니고 있는 것은?': '서양 철학',
#  '철학이라는 용어가 유래한 언어는?': '고대 그리스어',
#  '분석 철학과 함께 서양 철학의 두 가지 주요 전통 중 하나는?': '대륙 철학',
#  '철학적인 질문은 실험을 통해서 답변해야만 하는 무슨 사항을 지니고 있지 않는가?': '의무사항',
#  '자연과학의 여러 분과들로 발전하여 과학 혁명으로 가는 길을 마련한 철학은?': '자연 철학',
#  '철학의 문제 외에도 철학에서 다루고 있는 분야는?': '자연 과학',
#  '순수 수학, 물리학, 천문학, 생물학에 관한 책을 쓴 사람은?': '아리스토텔레스',
#  '17세기 이전까지 순수 수학, 물리학, 천문학, 생물학 등을 다루었던 학문은?': '철학',
#  '고대 세계에서 전문적인 과학으로, 철학으로부터 독립된 학문은?': '수학',
#  '서양 철학이라는 용어의 지정학적 경계는 몇세기에 걸쳐 형성 되었는가?': '19-20세기',
#  '서양철학은 최근에 어디에서 유래된 것으로 형성 되었는가?': '유럽',
#  '19-20세기에 걸쳐 지정학적 경계가 형성된 것은?': '서양 철학',
#  '19-20세기에 국가나 철학, 문화에 대해 "서양"이라는 개념이 없었던 사람들의 나라는?': '유럽',
#  '최근의 시각에서 서양 철학이 주로 유래한 대륙은?': '유럽',
#  '서양 철학의 지정학적 경계가 형성된 시기는 19세기와 몇 세기인가?': '20세기',
#  '신의 존재와 본성을 다루는 학문은?': '신학',
#  '20세기 이르기까지 신학적인 질문을 답하려고 노력한 철학은?': '서양 철학자',
#  '아리스토텔레스가 철학의 중심 분야로 간주한 것은?': '신학',
#  '아리스토텔레스가 신학이 뻗어나온 곳이라고 간주한 것은?': '형이상학',
#  '아리스토텔레스가 신학의 상위 분야로 보았던 것은?': '형이상학',
#  '세계 종교의 차이를 비교하는 종교 연구의 분야는?': '비교 종교학',
#  '임세영은 무엇을 경영하던 사람이었습니까?': '정육점',
#  '임세영은 시국이 불안정하던 때에 자라나서 무엇을 구할 뜻을 품게 됩니까?': '난세',
#  '임세영은 어느 스승 밑에서 무예 수련을 시작합니까?': '종홍산',
#  '임세영은 중국 광동성 남해현에서 어떤 가게를 운영하였는가?': '정육점',
#  '마을사람들은 임세영을 뭐라고 불렀는가?': '돼지장수 임(林)군',
#  '임세영은 무예를 연마하기 위해 누구의 제자로 입문하였는가?': '고금성',
#  '임세영이 무예를 시작하게 된 이유가 무엇인가?': '난세를 구할 큰 뜻을 품고',
#  '생활이 어려워 무예를 중단한 임세영은 누구의 밑에서 다시 시작했는가?': '종홍산(鐘洪山)',
#  '임세영은 광주 전역에 수배령이 내려지자 달아났다가 청나라를 멸망시키고 어떤 나라를 세우는데 공헌했습니까?': '중화민국',
#  '중화민국 수립후 광주로 돌아온 임세영이 차린 것은 무엇입니까?': '도장',
#  '임세영은 홍콩으로 이주하여 무관을 열고 무엇을 가르치며 제자를 양성했습니까?': '홍가권',
#  '중화민국 수립 후 임세영은 자신의 스승이었던 누구를 재조명하는 작업에 착수하였는가?': '황비홍',
#  '임세영은 홍콩으로 이주하여 무관을 열고 무엇을 가르쳤는가?': '홍가권',
#  '임세영은 어느나라를 멸망시키고 중화민국을 세우는데 공헌하였는가?': '청나라',
#  '임세영이 재조명한 스승의 이름은?': '황비홍',
#  '임세영이 다시 개량한 권법의 이름은?': '홍가권',
#  '임세영이 광주에서 도장을 열었을 때, 대련을 신청한 관장은 무슨 도장을 운영 중이었습니까?': '소림 무예',
#  '임세영에게 대련을 신청했다가 패배한 소림 무예 도장의 관장은 18반 병기 중 무엇을 들고 다시 임세영을 찾아갑니까?': '쌍극',
#  '소림 무예 도장의 관장이 임세영과의 싸움 이후 부상을 치료하기 위해 찾아간 사람은?': '황비홍',
#  '소림 무예 도장의 관장은 무엇을 들고 임세영을 찾아갔는가?': '쌍극',
#  '임세영에게 대련을 신청하였으나 패배한 사람은 누구인가?': '소림 무예 도장의 관장',
#  '소림 무예 도장의 관장이 패배한 이후 찾아간 인물은?': '황비홍',
#  '반기문이 졸업한 중학교의 이름은 무엇인가?': '충주중학교',
#  '반기문이 미국 연수에서 만난 미국 대통령의 이름은 무엇인가?': '존 F. 케네디',
#  '반기문은 서울대학교의 무슨 학과를 나왔는가?': '외교학과',
#  '반기문이 고등학교 2학년 때 출전한 영어경시대회의 주최단체는?': '미국 적십자사',
#  '반기문이 고등학교 3학년 때 미국에서 만난 미국 대통령의 이름은?': '존 F. 케네디',
#  '반기문이 외무고시에서 거둔 성적은?': '차석',
#  '2003년 대한민국의 신용등급의 전망을 긍정적에서 부정적으로 낮춘 미국의 신용평가기관의 이름은 무엇인가?': '무디스',
#  '무디스에 의해 한국의 국가신용등급이 부정적으로 내려갔을 당시의 대한민국의 대통령은 누구였는가?': '노무현',
#  '2003년 참여정부가 무디스, 피치 등의 신용평가기관에 보낸 대표단은 반기문을 비롯해 총 몇 명인가?': '3인',
#  '반기문이 참여정부에서 맡은 직위는?': '외교안보보좌관',
#  "2003년 2월 11일 한국의 국가신용등급 전망을 '부정적'으로 낮춘 미국의 신용평가기관은?": '무디스',
#  '참여정부가 반기문을 비롯한 3인의 대표단을 신용평가기관에 보낸 날짜는?': '2003년 3월 9일',
#  '반기문이 외교안보보좌관을 지낸 정부는?': '참여정부',
#  '2003년 2월 무디스가 대한민국의 국가신용등급 전망을 낮추려고 한 이유로 부시정부가 반미적이라고 본 인물은?': '노무현',
#  '반기문의 읍소로 신용등급 전망만 낮추고 실질적인 신용등급 하향 조치를 취하지 않은 신용평가기관은?': '무디스',
#  '반기문에 의해 2004년 7월 한국으로 입국되었던 400여명의 탈북자들이 모여있었던 나라의 이름은 무엇인가?': '베트남',
#  '반기문은 평화협정 체제로 바꾸려는 조선민주주의인민공화국의 주장을 무엇을 해체하려는 전술이라고 판단하였는가?': '유엔사',
#  '노무현 대통령과 참여정부 각료들은 북한에 대해 어떤 정책을 추구했나?': '유화정책',
#  '2004년 7월 반기문은 어디에 모여있던 400여명의 탈북자들을 한국에 입국시켰나?': '베트남',
#  '2005년 당시 미 국무장관의 이름은?': '콘돌리자 라이스',
#  '노무현 대통령의 대북 정책은?': '유화정책',
#  '노무현 정부 당시 미국의 국무장관은?': '콘돌리자 라이스',
#  '2005년 8월경 NSC의 상임위원장의 이름은 무엇인가?': '정동영',
#  '9.19 공동성명 타결 시 외교부에 감시병으로 파견되었던 인물의 이름은 무엇인가?': '박선원',
#  '2006년 7월 조선민주주의인민공화국이 발사한 미사일의 이름은 무엇인가?': '대포동 2호',
#  '반기문이 2005년 8월 미국 워싱턴을 방문해서 발언했던 방침은 무엇인가?': '선 6자회담, 후 평화협정',
#  '2005년 당시 국가안전보장회의 상임위원장의 이름은?': '정동영',
#  '9.19 공동성명이 타결될 당시 반기문을 감시하기 위해 청와대에서 파견한 사람의 이름은?': '박선원',
#  '반기문에게 냉전적 시각을 이유로 질책한 인물은?': '정동영',
#  '노무현 정부가 반기문을 감시하기 위해 파견한 인물은?': '박선원',
#  '북한이 1차 핵실험을 감행한 해는?': '2006년',
#  '반기문이 유엔 차기 사무총장 선거 출마 선언을 한 날짜는 언제인가?': '2006년 2월 14일',
#  '반기문이 유엔 사무총장에 당선되었던 날은 언제인가?': '2006년 10월 14일',
#  '8대 유엔 사무총장 선거를 위해 10월 2일의 비공식 설문조사까지 기권표를 던진 나라의 이름은 무엇인가?': '일본',
#  '반기문이 유엔 차기 사무총장 선거에 공식적으로 출마 선언을 한 날짜는?': '2006년 2월 14일',
#  '2006년 당시 한국에서 반기문의 직위는 무엇이었나?': '외교통상부 장관',
#  '2006년 당시 반기문과 유엔 사무총장직을 놓고 경쟁한 사람의 이름은?': '샤시 타루르',
#  '반기문이 한국인 최초로 당선된 직위는?': '유엔 사무총장',
#  '반기문과 경쟁하던 샤시 타루르의 국적은?': '인도',
#  '반기문은 안보리 15개 나라 중 몇 나라의 지지를 받았는가?': '14개',
#  '2007년 1월 아프리카 연합 정상회의가 열린 나라의 이름은 무엇인가?': '에티오피아',
#  '반기문의 최초 외부 순방 당시 수단의 대통령 이름은 무엇인가?': '오마르 알바시르',
#  '다르푸르 분쟁 당시 유엔 안전 보장 이사회에 의해 분쟁 지역으로의 진입이 승인 된 유엔 평화유지군은 총 몇명인가?': '26,000명',
#  '2007년 1월 아프리카 연합 정상회의가 열린 나라는?': '에티오피아',
#  '반기문이  2007년 1월 아프리카 연합 정상회의에 순방하고 만난 수단의 대통령 이름은?': '오마르 알바시르',
#  '2007년 7월 31일 유엔 안전 보장 이사회가 승인하여 다르푸르 분쟁지역에 파병될 유엔 평화유지군의 병력 수는?': '26,000명',
#  '반기문이 다르푸르 분쟁 해결이 임기 중 최우선 목표 중 하나라고 천명한 도시는?': '아디스아바바',
#  '반기문은 오마르 알바시르와 만나 분쟁 지역에 파견하기로 한 단체는?': '유엔 평화유지군',
#  '유엔 안전 보장 이사회가 다르푸르 분쟁 지역에 파견한 유엔 평화 유지군의 숫자는?': '26,000명',
#  '반기문이 2016년 6월 이스라엘에 방문할 당시 이스라엘의 총리의 이름은 무엇인가?': '베냐민 네타냐후',
#  '반기문이 안전보장이사회에서 유대인 정착촌을 확대하는 이스라엘을 지적했던 날은 언제인가?': '2016년 1월 26일',
#  '2016년 1월 26일 안전보장이사회의 중동 관련 토론에서 반기문이 언급한 강 이름은?': '요르단 강',
#  '2016년 6월 반기문이 이스라엘을 직접 방문하여 만난 이스라엘 총리의 이름은?': '베냐민 네타냐후',
#  '2016년 6월 반기문이 만난 팔레스타인 자치정부 수반의 이름은?': '마흐무드 압바스',
#  '2016년 반기문이 요르단 강 서안의 유대인 정착촌 확대 문제로 비판한 나라는?': '이스라엘',
#  '유엔이 팔레스타인 분쟁 해결책으로 제시해 온 것은?': '2국가 해법',
#  '2016년 9월 15일 미국을 방문한 대한민국의 국회의장 이름은 무엇인가?': '정세균',
#  '정동춘이 이사장으로 있는 재단의 이름은 무엇인가?': 'K스포츠재단',
#  '2015년 11월 라디오에 출연하여 반기문의 친박에 관한 언급을 한 국회의원은?': '홍문종',
#  '2016년 9월 15일 미국을 방문한 국회의장의 이름은?': '정세균',
#  '반기문이 박근혜 대통령을 비판하며 친박계와 선을 그은 날의 날짜는?': '2016년 12월 16일',
#  '2016년 1월 반기문이 역사가 높게 평가할 것이라고 평가한 협상은?': '위안부 문제 협상',
#  '제3지대가 반기문 총장을 옹립하여 새로운 당을 만드는 데 이사장으로서 노력하고 있다고 말한 사람은?': '정동춘',
#  '세계여성평화그룹의 영어 약어는 무엇인가?': 'IWPG',
#  '세계여성평화그룹의 대표로 세계여성평화그룹의 홍보 동영상에 반기문과 함께 찍은 사진이 있는 인물의 이름은 무엇인가?': '김남희',
#  '세계여성평화그룹의 홍보 동영상에 있는 반기문 총장과 함께 찍은 사진 속 인물의 이름은?': '김남희',
#  '세계여성평화그룹이 신천지와 친밀한 관계라는 의혹에 대해 반기문에게 해명을 요구한 정당은?': '더불어민주당',
#  '세계여성평화그룹의 홍보 동영상에서 반기문 총장과 나란히 서서 사진을 찍은 인물은?': '김남희',
#  '김남희 세계여성평화그룹 대표가 믿는 종교는?': '신천지',
#  '2015년 세계여성의 날 기념행사가 열린 도시는?': '뉴욕',
#  '2016년 11월 반기문을 강하고 인간적인 지도자이며 한국의 대통령에 적합한 인물이라고 소개한 미국의 경제 전문지의 이름은 무엇인가?': '포브스',
#  '안보리 결의안에 대해서 거부권을 행사한 나라는 어디인가?': '러시아',
#  '2016년 11월 반기문은 강하고 인간적인 지도자로 대통령에 적합한 리더쉽을 가졌다고 보도한 미국의 경제 전문지는?': '포브스',
#  "'적합한 리더로서의 반기문'이란 글을 기고한 국제 외교안보 전문가의 이름은?": '앤더스 코',
#  '강인한 외교의 사례로 반기문은 사우디아라비아가 어느 나라를 공습한 것을 비판하였나?': '예멘',
#  '반기문이 강하고 인간적인 지도자이며 한국 대통령으로 적합한 인물이라고 보도한 미국의 경제지는?': '포브스',
#  '시리아 민간인 보호를 목표로 한 안보리 결의안에 거부권을 행사한 나라는?': '러시아',
#  '반기문이 예멘을 공습하여 비판한 나라는?': '사우디아라비아',
#  '금강산의 여름 이름은?': '봉래산',
#  '금강산의 가을 이름은?': '풍악산',
#  '금강산의 겨울 이름은?': '개골산',
#  '금강산의 다른 이름으로 여름에 불리는 이름은?': '봉래산',
#  '금강산의 총 면적은?': '530제곱킬로미터',
#  '금강사느이 어느 지역 남쪽이 신금강으로 분류되는가?': '외금강',
#  '대대로 많은 예술가들의 표현 대상이 될 정도로 아름답기로 유명한 산은?': '금강산',
#  '여름의 금강산은 무엇이라고 불리는가?': '봉래산',
#  '바위 뼈 산이라는 뜻을 지닌 금강산의 겨울 이름은?': '개골산',
#  '금강산의 이름과 연관된 산스크리트 단어로 번개와 다이아몬드를 뜻하는 말은?': '바이아라',
#  "금강산은 어느 계절에 특히 '금강산'이라고 불리는가?": '봄',
#  '각종 문헌과 기록에 등장하는 금강산의 별칭은 총 몇개인가?': '9가지',
#  '금강산을 겨울에 부르는 이름은?': '개골산',
#  '금강산은 어떤 종교의 영지로 알려져 있는가?': '불교',
#  '각종 문헌과 기록에 등장한 금강산의 별칭은 총 몇 가지 인가?': '9가지',
#  '일천 이만 봉이 단풍으로 물든 가을의 금강산은 무엇이라고 불리는가?': '풍악산',
#  '금강산이 여러가지 이름 중에 금강산이라는 이름으로 널리 알려진 이유는 금강산이 무엇으로 알려져있기 때문인가?': '불교의 영지',
#  '금강산을 주로 이루고 있는 암석은?': '화강암',
#  '금강산의 기암괴석을 형성한 지질운동으로 1천만년 전부터 진행된 것은?': '궁융상지괴응기 운동',
#  '특유의 지질 활동과 같이 금강산을 만든 요소는?': '독특한 기후',
#  '금강산에 가장 널리 분포하는 암석은?': '화강암',
#  '금강산의 기암괴석은 어ㄸ\nㅓㄴ 운동으로 형성되었는가?': '궁융상지괴응기 운동',
#  '금강산의 지질층은 무엇으로 이루어져 있는가?': '여러 종류의 암석',
#  '금강산의 특이한 지형과 기이한 바위는 1천만 년 전부터 현세까지 진행된 어떤 운동으로 형성되었나?': '궁융상지괴응기',
#  '금강산의 주봉은?': '비로봉',
#  '금강산의 분설담 위에 있는 절의 이름은?': '보덕암',
#  '금강산에 있는 고려시대의 뛰어난 조각 솜씨를 볼 수 있는 것은?': '삼불암',
#  '금강산에 있는 것으로 40미터인 암벽에 조각된 마애불의 이름은?': '묘길상',
#  '금강산의 보덕암은 어디 위에 세워져 있는가?': '분설담',
#  '주분서령의 서쪽에 있는 지역으로 금강산의 주봉인 비로봉과 여러 폭포가 있는 곳은 어디인가?': '내금강',
#  '팔담의 하나인 분설담 위에 세워진 독특한 암자는 무엇인가?': '보덕암',
#  '금강산의 폭포로 조선 3대 폭포 중 하나는?': '구룡폭포',
#  '금강산의 구역 가운데 삼선암, 독선암, 귀면암 등을 포함하고 있는 곳은?': '만물상 구역',
#  '개성의 박연폭포, 설악산의 대승폭포와 같이 조선 3대 폭포로 꼽히는 폭포는?': '구룡폭포',
#  '비봉폭포의 높이는?': '139미터',
#  '용바위, 흔들바위, 선하 폭포, 무지개 다리 등이 있는 금강산의 구역은?': '선하 구역',
#  '개성의 박연폭포, 설악산의 대승폭포와 더불어 조선 3대 폭포로 뽑히는 구룡폭포는 어디에 위치하고 있는가?': '구룡연',
#  '구룡폭포의 높이는?': '74미터',
#  '139미터에 달하는 높이와 장쾌한 물줄기로 이름나 있는 폭포의 이름은 무엇인가?': '비봉폭포',
#  '1698년에 남택하가 "금강산의 얼굴빛"이라는 뜻으로 이름을 지어준 금강산 내의 지역은?': '해금강',
#  '소가 누운 모양인 삼일포에 있는 섬은?': '와우섬',
#  '해금강이라는 이름을 붙인 고성 군수의 이름은?': '남택하',
#  '신선 또는 화랑이 3일 동안 머물러 가서 붙은 해금강의 석호 이름은?': '삼일포',
#  '해금강의 와우섬은 어떤 동물이 누운 모양이라고 하여 붙은 이름인가?': '소',
#  '경치가 너무 좋아 신선 또는 화랑들이 3일 동안 머물고 갔기 때문에 붙여진 호수의 이름은 무엇인가?': '삼일포',
#  '소가 누운 모양을 하고 있는 큰 섬의 이름은 무엇인가?': '와우섬',
#  '해만물상이라고 불리며, 육지와는 거리를 두고 바닷가에 홀로 솟아 있는 봉우리의 이름은?': '향로봉',
#  '신증동국여지승람에 기재된 금강산 내 사찰 수는?': '108개',
#  '금강산의 절로 2004년 복원을 시작해 2007년 복원완료된 사찰은?': '신계사',
#  '신증동국여지승람에는 금강산에 몇개의 사찰이 있었다고 기록되어 있는가?': '108개',
#  '4대 사찰 이외에 금강산의 사찰이 폐쇄된 때는?': '조선 왕조',
#  '금강산의 4대 사찰이 대부분 파괴된 사건은?': '한국전쟁',
#  '신증동국여지승람에 따르면 금강산에 있었던 사찰의 수는 총 몇 개인가?': '108개',
#  '가장 먼저 건립된 사찰의 이름은 무엇인가?': '유점사',
#  '금강산 4대 사찰 중 한국전쟁을 거치고도 파괴되지 않고 남아있는 사찰은 어디인가?': '표훈사',
#  '북한이 금강산을 보호하는 법률은?': '금강산 관광지구법',
#  '금강산의 보호를 위한 법률를 2002년 10월 23일에 채택한 북한의 기구는?': '최고인민회의 상임위원회',
#  '북한의 금강산 관광지구법이 통과된 해는?': '2002년',
#  '금강산 관광지구법 28조에 따라 어느 처벌까지 가능한가?': '추방',
#  '조선민주주의인민공화국 최고인민회의 상임위원회가 금강산을 엄격히 보호하기 위해 채택한 법의 이름은?': '금강산 관광지구법',
#  '개발자가 관광지의 나무, 경치, 천연기념물을 훼손하는 행위가 금지되는것은 금강산 관광지구법의 몇 조에 속하는 내용인가?': '금지되며(11조),',
#  '현대그룹의 창업자는?': '정주영',
#  '금강산 관광개발 의정서의 체결 연도는?': '1989년',
#  '한국 최초의 호텔식 테마 여객선은?': '설봉호',
#  '금강산 관광이 본격적으로 시작된 해는?': '1998년',
#  'DMZ를 통과하는 금강산 육로관광이 시작된 해는?': '2003년',
#  '2005년 6월에 금강산 관광객은 몇명을 돌파하였는가?': '100만 명',
#  '1989년 방북하여 금강산 관광개발 의정서를 체결한 현대그룹 창업자의 이름은?': '정주영',
#  '2001년 1월 6일부터 3년동안 금강산 관광에 이용했던 한국 최초의 호텔식 테마 여객선의 이름은?': '설봉호',
#  '금강산의 관광객 수는 2008년 말 기준으로 얼마에 달했는가?': '195만 명',
#  '외금강 코스가 개방된 해는?': '1998년',
#  '남측 강원도가 DMZ 관광청을 발족한 해는?': '2008년',
#  'DMZ 관광청이 발족한 해는?': '2008년',
#  '강원도는 금강산과 어느산을 묶어 세계적인 관광지대로 만들고자 하는가?': '설악산',
#  '현재 금강산 관광은 개별적이 아닌 일정에 따라 누구를 통해 이루어지는 형태로 되어있는가?': '가이드',
#  '설악산과 금강산을 묶어 세계적인 관광지대로 가꾸는 계획을 가지고 있는 강원도의 관청 이름은?': 'DMZ 관광청',
#  '체스를 두는 선수들은 몇개의 백색 또는 흑색기물을 갖고 시작하는가?': '16개',
#  '체스보드에서 "열"은 뭐라고 불리는가?': '랭크',
#  '체스보드에서 "행"은 뭐라고 불리는가?': '파일',
#  '체스에서 선수들은 각각 몇 개의 흑색 또는 백색 기물을 갖고 시작하는가?': '16개',
#  '체스를 두는 사람 기준으로 제일 오른쪽 아래 있는 정사각형은 무슨 색이여야 하는가?': '흰색',
#  '체스보드에서 랭크는 무엇을 부르는 말인가?': '열',
#  '체스보드를 구성하는 정사각형의 갯수는?': '64개',
#  '체스에서 각각의 선수들이 갖고 시작하는 기물의 갯수는?': '16개',
#  '체스보드에서 열을 지칭하는 말은?': '랭크',
#  '앙파상 규칙은 상대의 폰이 몇 칸 전진 된 직후에만 적용할 수 있는가?': '두칸',
#  '흑색 폰이 두칸 전진할 때 어느 랭크에 백색 폰이 있다면 앙파상 규칙으로 흑색 폰을 잡을 수 있게 되는가?': '바로 옆 파일의 5번째',
#  '앙파상 규칙을 적용하기 위해 상대방의 폰이 움직인 칸의 갯수는?': '두칸',
#  '폰이 두칸 전진했을 때 바로 옆 파일에 상대의 폰이 존재할때 상대가 움직인 폰을 잡을 수 있는 규칙은?': '앙파상 규칙',
#  '모든 폰이 프로모션 되었다면 한 선수가 동시에 몇개의 퀸을 가지고 있을 수 있냐?': '9개',
#  '프로모션은 폰이 몇 번째 랭크로 전진하는 순간 이루어지냐?': '8번째 랭크',
#  '폰이 어디까지 전진하게 되면 프로모션을 하게 되는가?': '8번째 랭크까지',
#  '폰을 프로모션할 때 퀸, 룩, 비숍 외 바꿀 수 있는 다른 한 가지는 무엇인가?': '나이트',
#  '폰이 프로모션을 하기 위해 전진해야 하는 랭크는?': '8번째 랭크',
#  '프로모션된 폰을 나타낼 기물이 부족할 때 필요한 기물을 달라고 요구해야 하는 사람은?': '심판',
#  '체스에서 가장 강력한 기물은?': '퀸',
#  '킹이 상대의 기물에 의해 체크를 당하고 있고, 어떠한 방법으로도 피할 수 없을 때, 무엇을 당했다고 하는가?': '체크메이트',
#  '체크메이트가 발생하면 경기는 체크메이트를 당한 사람의 무엇으로 종료가 되냐?': '패배',
#  '상대의 기물에 킹이 체크 당하며 피할 수 있는 방법이 없는 상황을 무엇이라 하는가?': '체크메이트',
#  '다른 기물들과 달리 경기 종료까지 체스보드 밖으로 나오지 않는 기물은?': '킹',
#  '킹이 상대의 기물에 의해 체크를 당하고 있고 무슨 방법을 쓰더라도 체크를 피할 수 없는 상황을 이르는 말은?': '체크메이트',
#  '기물 중에서 체스보드 밖으로 나오거나 다른 기물에 의하여 잡히지 않는 기물은?': '킹',
#  '체크메이트를 당한 사람의 경기 결과는?': '패배',
#  '기권한다는 뜻으로 기보에 적는 영어 단어는?': 'resigns',
#  '기권을 선언할때 기권한다고 말을 하거나 어디에 기권한다고 적으면 될까?': '기보',
#  '본인의 킹을 직접 쓰러뜨리는 것은 무슨 의미인가?': '기권',
#  '흑이 기권한다면 기보엔 "resigns"와 더불어 무엇을 적어야하는가?': '1-0',
#  '양측 모두 어떤 시점에서든지 선언할 수 있는 것은?': '기권',
#  '자주 사용되지는 않지만 자신의 킹을 넘어뜨리는 것이 의미하는 것은?': '기권',
#  '심판을 부르기 위해 멈추는 것은?': '양측 시계',
#  '시간제한이 주어진 대국에 대해서 무엇이 적용되었다고 하는가?': '타임 컨트롤',
#  '세계 체스 선수권에서는 처음 40수에 대하여 각각 몇 분이 주어지나?': '120분',
#  '체스에서 시간제한이 있는 대국은 무엇이 적용됐다고 말하는가?': '타임 컨트롤',
#  '세계 체스 선수권에서 처음 몇 수에 각각 120분이 주어지는가?': '40수',
#  '자신의 시간을 모두 사용하였지만 상대방이 자신을 체크메이트 할 수 없는 상황일 때 승부의 결과는?': '무승부',
#  '처음 40수에 대하여 각각 120분, 다음 20수에 대하여 각각 60분씩 주는 대회의 이름은?': '세계 체스 선수권',
#  '캐슬링을 할 경우, 반드시 무엇부터 움직여야 하나?': '킹',
#  '캐슬링이 규칙에 어긋나는 경우에는 터치-무브 규칙은 무엇에게 적용되나?': '룩에게',
#  '미국의 체스협회 에서는 무엇을 만진 경우에도 캐슬링 의도가 있다면 캐슬링을 허용하나?': '룩',
#  '캐슬링을 할 때  먼저 움직여야하는 기물은 무엇인가?': '킹',
#  '룩을 먼저 만진 경우에도 캐슬링의 의도가 있다면 허용해주는 협회는?': '미국의 체스 협회',
#  '캐슬링을 할 때 꼭 움직여야 하는 것은?': '킹',
#  '캐슬링의 의도가 있었다면 룩부터 만졌어도 캐슬링을 허용하는 협회는?': '미국의 체스 협회',
#  '캐슬링이 규칙에 어긋나는 경우에 터치-무브 규칙이 적용되는 기물은?': '룩',
#  '토너먼트 경기는 일반적으로 어떤 시간제한 안에서 이루어지나?': '타임 컨트롤',
#  '체스 선수들이 체스를 둘 때, 자신을 시간을 모두 사용 할 경우에는 어떻게 되는가?': '패배',
#  '일반적으로 타임 컨트롤 안에서 이루어지는 경기는?': '토너먼트 경기',
#  '자신의 시간을 모두 사용한 선수가 맞이하는 결과는?': '패배',
#  '시간초과 승리의 기준으로 남은 기물을 이용해 체크메이트 강제 가능 여부를 두고 있는 곳은?': 'USCF',
#  'USCF규칙 14E를 적용할 때 상대에겐 어떤 기물이 없어야 하는가?': '폰',
#  '시간 초과에 대해 세계 체스 연맹 규칙과 다른 규칙을 가지고 있는 협회는?': '미국 체스 협회',
#  '시간 초과로 승리할 조건을 남은 기물로 체크메이트를 강제할 수 있는지를 기준으로 판단하는 곳은?': 'USCF',
#  '시간 초과로 승리할 조건을 상대방을 체크메이트 할 가능성으로 판단하는 곳은?': 'FIDE',
#  "체스에서 '#'은 무엇으로 불리는가?": '체크메이트',
#  '대수기보법에서 가로, 행은 무엇이라고 불리는가?': '랭크',
#  '체스보드에서 열은 무엇이라 부르는가?': '파일',
#  '대수기보법에서 시간이 몇 분 미만으로 남았을 때 기록의 의무가 없는가?': '5분',
#  '체스보드의 열을 이르는 말은?': '파일',
#  '특정 칸의 이름을 붙일 때 파일을 읽은 후에 읽는 것은?': '랭크',
#  '심판이 언제나 볼 수 있어야 하는 것은?': '기보',
#  '게임 중 체스보드 위 시작 포지션이 규칙과 다른 것을 발견하면 게임은 어떻게 되는가?': '재시작',
#  '체스보드 위 불법인 수나 올바르지 못한 위치의 기물이 발견되면 어느 시점으로 게임을 되돌리는가?': '잘못된 수가 두어지기 전',
#  '체스보드가 잘못 놓인 경우 올바른 방향으로 돌리는 것은?': '체스보드',
#  '게임 도중 게임의 시작 포지션이 규칙에 어긋나 있었다는 것이 발견되면 게임의 진행은 어떻게 되는가?': '재시작',
#  '한 변이 몇 mm인 체스보드가 가장 많이 쓰이는가?': '57 mm',
#  '체스에서 기물들의 높이는 무엇의 높이에 따라 적절한 비율로 정해지나?': '킹',
#  '체스보드 안 정사각형 한 변의 길이는 킹의 지름의 몇 배 정도가 적당한가?': '1.25배에서 1.3배',
#  '가장 많이 쓰이는 체스보드 정사각형 한 변의 길이는 얼마인가?': '57 mm',
#  '가장 많이 쓰이는 체스보드의 한 변의 길이는?': '57 mm',
#  '킹의 높이와 비교하여 적당한 밑면 지름의 비율은?': '40~50%',
#  '킹을 제외한 기물들의 높이의 기준이 되는 것은?': '킹',
#  '중세시대에는 폰을 무엇으로만 프로모션 할 수 있었냐?': '퀸',
#  '비숍이 대각선 방향으로 두 칸씩 다른 기물을 넘어서 행마 할 수 있는 나라는?': '아랍',
#  '현대 체스의 규칙은 몇 세기 이탈리아에서 가장 처음 만들어졌는가?': '13세기',
#  '이전에 "fers" 혹은 "farzin"이라 불린 기물은 무엇인가?': '퀸',
#  '6세기 체스와 유사한 게임이 시작된 나라는?': '인도',
#  '13세기에 현대적인 체스 규칙이 만들어진 나라는?': '이탈리아',
#  '중세시대에 폰이 프로모션할 수 있던 유일한 기물은?': '퀸',
#  '티베트고원의 면적은?': '약 250만 평방 킬로미터',
#  '티베트고원은 인도-호주 플레이트와 어떤 플레이트가 충돌해서 생성됐는가?': '유라시아 플레이트',
#  '티베트 고원의 면적은?': '250만 평방 킬로미터',
#  '인도-호주 플레이트와 충돌해 티베트 고원을 생성한 플레이트는?': '유라시아 플레이트',
#  '티베트 고원의 평균 고도는?': '5,000미터',
#  '티베트 고원을 다른 말로 어떤 고원이라고 부르는가?': '칭짱(青藏)고원',
#  '티베트 고원은 최저 몇 도까지 기온이 떨어지는가?': "영하 40'C",
#  '아시아에서 인구밀도가 가장 희박한 곳은?': '커커시리',
#  '전 세계에서 인구밀도가 가장 희박한 지역은?': '남극대륙',
#  '전 세계에서 가장 인구밀도가 희박한 지역은?': '남극대륙',
#  '티베트 고원의 북동쪽에 맞닿아 있는 산맥의 이름은?': '치롄 산맥',
#  '티베트 고원의 북동쪽 치롄 산맥 너머에 있는 지역은?': '고비 사막',
#  '전 세계애서 남극대륙과 그린란드 다음으로 인구밀도가 희박한 지역은 어디인가?': '커커시리',
#  '티베트 고원 북동쪽에 있는 산맥으로 고비사막과 경계를 이루는 곳은 어디인가?': '치롄 산맥(Qilian Range)',
#  '티베트고원이 형성되기 시작한 시기는?': '신생대 초기(약 5500만 년 전)',
#  '인도 몬순 시기, 남쪽의 습한 열대 공기는 어느 산맥에 막혀 비그늘을 형성하는가?': '히말라야 산맥',
#  '티베트 고원에서 발원하는 강은?': '황허',
#  '인도 몬순 시기에 남쪽으로부터 오는 습한 공기로 인해 매우 건조해지는 곳은?': '티베트 고원',
#  '티베트 고원에서 발원하는 강들이 유실되는 토양의 양이 전 세계에서 차지하는 비율은?': '1/4',
#  '지구 온난화로 빙하가 녹아 위험한 철도는?': '칭짱철도',
#  '티베트 고원이 생성되기 시작한 시기는 언제인가?': '신생대 초기(약 5500만 년 전)',
#  '인도 몬순 시기는 언제인가?': '6월에서 10월',
#  '도미니카 공화국 위조여권으로 일본에 입국하려했던 년도가 몇년도인가?': '2001년',
#  '김정남이 위원장을 맡은 곳을 적으시오.': '조선콤퓨터쎈터',
#  '조선콤퓨터쎈터 위원장을 맡았던 사람은?': '김정남',
#  '1998년 국가안전보위부 제1차장이자 직무대행을 맡은 사람은?': '김영룡',
#  '김영룡이 숙청된 이후 김정남은 어느 조직 제1차장으로 임명되었나?': '국가안전보위부',
#  '김정남이 2001년 위조 여권으로 밀입국을 시도한 나라는?': '일본',
#  'IT 분야에 관심이 많은 김정남이 위원장으로 근무한 센터는?': '조선콤퓨터쎈터(조선컴퓨터센터)',
#  '쿠알라룸푸르 국제공항이 위치한 나라를 적으시오': '말레이시아',
#  '김정남이 죽은 시간을 정확히 적으시오': '2017년 2월 13일 오전 9시경',
#  '김정남 암살 작전이 진행시작된 년도를 적으시오': '2012년',
#  '김정남이 사망한 년도는?': '2017년',
#  '어느공항에서 김정남이 살해되었나?': '쿠알라룸푸르 국제공항',
#  '쿠알라룸푸르국제공항은 어느나라 공항인가?': '말레이시아',
#  '김정남을 살해한 배후와 사주한 일당의 국적은?': '조선민주주의인민공화국',
#  '김정남이 살해된 곳은?': '쿠알라룸푸르 국제공항',
#  '박형식은 제국의 아이들 멤버로 언제 데뷔하였는가?': '2010년 1월 15일',
#  '박형식이 주얼리S 뮤직비디오 주인공으로 참여한 곡은 무엇인가?': '데이트',
#  '박형식은 언제부터 검도를 배우기 시작하였는가?': '초등학교 3학년',
#  '박형식이라는 이름을 지어준 이의 직업은?': '스님',
#  '박형식이 재학중인 대학교는?': '디지털서울문화예술대학교',
#  '박형식이 데뷔한 남성 아이돌 그룹의 이름은?': '제국의 아이들',
#  '박형식이 데뷔한 아이돌 그룹의 이름은 무엇인가?': '제국의 아이들',
#  '박형식이 재학 중인 학교는 어디인가?': '디지털서울문화예술대학교',
#  '증강현실 연구의 시초가 된 사람은?': '이반 서덜랜드',
#  '실제의 환경에 가상의 환경을 반영하여 재구성한 기술은?': '증강현실',
#  '가상으로 꾸며진 세계를 일컫는 말은?': '가상현실',
#  '증강현실은 누가 발전시킨 것을 시초로 하여 연구되기 시작했는가?': '이반 서덜랜드',
#  '증강현실은 무엇과 무엇이 혼합된 형태인가?': '실제 환경과 가상의 객체',
#  '증강현실은 서덜랜드가 무엇을 발전시킨 것을 시작으로 연구가 시작되었는가?': 'see-through HMD',
#  '가상현실과 다르게 증강현실에서는 어떤 점을 사용자에게 제공하는가?': '현실감',
#  '역법에 따라 실제 예측을 하기 위해 행사는 계산을 칭하는 말로, 사회에 큰 영향을 미쳤던 학문은?': '역산',
#  '전근대 동아시아의 많은 국가에서 군주를 상징하던 별은?': '태양',
#  '전근대 동아시아에서 대개 태양으로 상징되던 지위는?': '군주',
#  '역법에 따라 실제 예측을 하기 위해 행하는 계산을 부르는 말은?': '역산',
#  '1 삭망월의 대략적인 평균치는?': '약 29.5306일',
#  '1 태양년의 대략적인 평균치는?': '약 365.2422일',
#  '1 삭망월의 평균치는 약 며칠인가요?': '29.5306일',
#  '1 태양년의 평균치는 약 며칠인가요?': '365.2422일',
#  '12 삭망월과 1태양년의 날짜 차이는?': '10일 혹은 11일',
#  '삭망월과 태양년의 날짜 차이를 없애기 위해 사용된 방법은?': '치윤법과 연대배치법',
#  '달력을 제작할 때 기초가 되는 계산법과 천문상수의 체계를 칭하는 법칙은?': '역법',
#  '기존의 역법을 폐기하고 새로운 역법을 편찬하는 것을 일컫는 말은?': '개력',
#  '중국 최초의 역법은?': '태초력',
#  '달력을 제작할 때에 기초가 되는 계산법과 천문상수의 체계를 무엇이라고 하나요?': '역법',
#  '기존의 역법을 폐기하고 새로운 역법을 편찬하는 것을 무엇이라고 하나요?': '개력',
#  '중국 최초의 역법은 무엇인가요?': '태초력',
#  '달력을 만들 때 기초가 되는 계산법과 천문상수의 체계를 이르는 말은?': '역법',
#  '중국 최최의 역법은?': '태초력',
#  '청나라의 역법은 무엇인가?': '시헌력',
#  '전한 시대에 제작되었으며, 연대배치법과 치윤법을 완전히 확립한 역법은?': '태초력',
#  '후대 역법의 시초가 되었으며, 일식과 월식의 예보를 위한 135개월 주기와 오행성이 운행 등의 예측을 통해 계산된 역법은?': '삼통력',
#  '후한 말, 달의 운행에 대한 새로운 연구 결과를 적용해 만들어진 유홍의 역법은?': '건상력',
#  '태초력은 전한 말에 유흠에 의해 증보되어 무엇이 되었나요?': '삼통력',
#  '위진남북조시대와 송나라 초기에 걸쳐 사용된 역법은?': '경초력',
#  '전한 말에 태초력을 증보하여 삼통력으로 만든 사람의 이름은?': '유흠(劉歆)',
#  '위진남북조시대와 송 초기에 걸쳐 200여 년 동안 사용된 역법은?': '경초력(景初曆)',
#  '19년에 7번 윤달을 삽입하는 치윤법인 장법을 폐지한다는 뜻을 지닌 법은?': '파장법',
#  '수나라가 남북조를 통일하면서 융합되어 만들어진 역법은?': '황극력',
#  '원가력의 계산 오류를 지적하고 파장법과 세차운동의 도입을 통한 개력을 주장한 사람은?': '조충지',
#  '원가력에 의한 계산이 천상고 일치하지 않게 된 것을 지적하며 개력을 주장한 사람은?': '조충지',
#  '19년에 7번 윤달을 삽입하는 치윤법을 말하는 것은?': '장법',
#  '파장법과 세차운동을 도입하자고 주장한 사람은?': '조충지(祖沖之)',
#  '조충지가 죽은지 10년후에 그가 주장한 것들이 사용된 역법은?': '대명력(大明曆)',
#  '원나라 세조 쿠빌라이 칸의 명령으로 원나라 초기 제작되어 명나라가 망할 때까지 사용된 역법은?': '수시력',
#  '중국 통일 직후 왕순과 곽수경에게 역법의 개력을 명령한 원나라 세조의 이름은?': '쿠빌라이 칸',
#  '세차운동으로 인해 1 태양년의 길이가 서서히 짧아지는 현상을 도입한 것으로, 수시력에서 채택한 계산법은?': '세실소장법',
#  '원나라 초기에 제작되어 명나라가 망할 때까지 사용된 역법은?': '수시력',
#  '수시력은 누가 왕순과 곽수경에게 개력을 명령한 것을 계기로 만들어졌나요?': '쿠빌라이 칸',
#  '원나라 초기에 제작되었으며 명이 망할때까지 사용된 역법은?': '수시력(授時曆)',
#  '수시력이 만들어 질떄 원나라의 군주는?': '쿠빌라이 칸',
#  '소토마요르가 첫 세계 주니어 기록을 세운 때는 언제인가?': '1984년 5월 19일',
#  '쿠바의 보이콧으로 소토마요르가 출전할 수 없었던 올림픽은?': '로스앤젤레스 올림픽',
#  '소토마요르가 첫 국제타이틀을 따낸 경기는?': '1987년 인디애나폴리스에서 열린 팬아메리칸 게임',
#  '1985년 파리의 세계 실내 선수권 대회에서 자신의 최고 기록 2.13m로 은메달을 획득한 사람은?': '소토마요르',
#  '소토마요르의 첫 국제 타이틀이라 할 수 있는 인디애나폴리스에서 1987년에 열린 게임은?': '팬아메리칸 게임',
#  '소토마요르가 처음 2m 기록을 세운 나이는?': '15세',
#  '소토마요르가 1984년에 처음 세운 세계 주니어 기록은?': '2.33m',
#  '소토마요르가 처음으로 국제 타이틀을 획득한 것은 몇년도인가?': '1987년',
#  '세계 실내 선수권 대회에서 소토마요르가 달성한 기록은?': '2.43m',
#  '소토마요르가 우승한 세계 실내 선수권 대회에서 5위를 한 카를로 타란하르트가 1년 전 세웠던 기록은?': '2.42m',
#  '소토마요르 자신의 기록 2.43m를 깬 세계 실내 선수권 대회를 주최한곳은?': '국제 아마추어 육상 연맹',
#  '소토마요르는  독일의 어느 선수와 2.33m로 함께 5위를 했나요?': '카를로 타란하르트',
#  '소토마요르의 부다페스트 경기 중 두 번째 시도에서 제거한 높이는?': '2.35m',
#  '소토마요르의 부다페스트 경기 최고 기록은?': '2.43m',
#  '바르세롤나 올림픽에서 높이뛰기에서 우승한 선수는?': '소토마요르',
#  '마지막 소토마요르를 포함 몇 명의 선수들이 결승을 다투었나?': '5명',
#  '이 경기에서 은메달을 딴 선수는?': '셰베리',
#  '소토마요르는 어느 올림픽에서 최고도의 높이로 우승했나요?': '바르셀로나 올림픽',
#  '바르셀로나 올림픽에서 소토마요르가 2.39m를 통과한 라운드는?': '마지막 라운드',
#  '바르셀로나 올림픽 높이뛰기 경기의 우승자는?': '소토마요르',
#  '바르셀로나 올림픽 높이뛰기 경기에서 소토마요르는 몇번 째 시도에 2.34m를 성공했는가?': '첫 시도',
#  '소토마요르가 부상을 당해 부진하게 된 년도는?': '1996년',
#  '애틀랜타 올림픽에서 우승을 하게 된 선수는 누구인가?': '미국의 찰스 오스틴',
#  '우승을 한 찰스 오스틴이 세운 기록은 얼마 였는가?': '올림픽 기록 2.39m',
#  '소토마요르는 실내 시즌  결과는 좋았으나, 실외 시즌의 문제점은?': '부상',
#  '첫 시도만 통과하고, 나머지는 실패하여, 11위에 머물게 된 올림픽은?': '애틀랜타 올림픽',
#  '소토마요르는 1996년 애틀랜타 올림픽에서 몇위를 기록했는가?': '11위',
#  '1996년 애틀랜타 올림픽의 우승자는?': '찰스 오스틴',
#  '소토마요르가 출전 정지를 받게 된 년도는?': '1999년',
#  '시드니 올림픽에서 소토마요르는 어떤 결과를 냈는가?': '은메달을 획득하였다.',
#  '1999년부터 출전 정지 후, 참가한 올림픽은?': '시드니 올림픽',
#  '국제 아마추어 육상 연맹이 소토마요르의 출전 금지를 줄이지 말았어야 했다고 한 사람은?': '스테판 홀름',
#  '소토마요르가 2000년 시드니 올림픽 높이뛰기 경기에서 얻은 메달은?': '은메달',
#  '소토마요르가 2000년 시드니 올림픽 높이뛰기 경기에서 은메달을 획득했을 때의 기록은?': '2.32m',
#  '2000년 시드니 올림픽 남자 높이뛰기 1위의 기록은?': '2.35m',
#  '싸이버스카이 지분을 대한항공에 모두 판 시기는 언제인가?': '2015년 11월',
#  '대한항공은 싸이버스카이 주식 9만9900주 전량을 얼마에 취득하였는가?': '63억 원',
#  '2014년에 싸이버스카이의 매출은 얼마였는가?': '49억300만 원',
#  '조양호 회장의 세 자녀 중 대한항공 전무는 누구인가?': '조현민',
#  '조양호 회장의 세 자녀의 편법 재산 증식으로 논란이 되었던 회사는 어디인가?': '싸이버스카이',
#  '싸이버스카이의 2014년 매출은 얼마였나?': '49억300만 원',
#  '2015년 11월 조양호 회장의 세 자녀가 대한항공에 지분을 판매한 회사명은?': '싸이버스카이',
#  '조양호 회장의 3자녀가 보유한 싸이버스카이 주식 9만 9000주 전량을 63억원에 취득한 회사는?': '대한항공',
#  '김이수가 태어난 날짜는?': '1953년 3월 24일',
#  '김이수가 졸업한 학교 이름은?': '서울대학교',
#  '김이수가 사법시험에 합격한 년도는?': '1977년',
#  '김이수는 몇년도에 태어났나?': '1953년',
#  '김이수가 태어난 곳은?': '전라북도 고창군',
#  '김이수는 어느대학을 졸업했나?': '서울대학교',
#  '김이수는 몇 년도에 태어났는가?': '1953년',
#  '김이수가 나온 고등학교의 이름은?': '전남고등학교',
#  '김이수가 1982년 판사로 임관하여 재직했던 법원 이름은?': '대전지방법원',
#  '김이수를 "함량미달 재판관 후보자"라고 말한 사람의 이름은?': '김재원',
#  '문재인 대통령에 의해 헌법재판소장으로 지명된 날짜는?': '2017년 5월 19일',
#  '김이수가 대전지방법원 판사로 임관한 년도는?': '1982년',
#  '김이수는 몇년도에 법원장으로 승진했나?': '2009년',
#  '김이수는 어느당 추천으로 헌법재판관이 되었나?': '민주통합당',
#  '김이수는 군대에서 상을 몇 개 받았는가?': '3개',
#  '김이수가 2009년 승진한 직책의 이름은?': '법원장',
#  '한 건물에 한 세대가 아닌 여러 세대가 함께 사는 주택 구조는 무엇인가?': '공동주택',
#  '1935년 내자동에 지어진 관사의 층수는 얼마인가?': '4층',
#  '1930년 회현동에 세워진 공동주택의 층수는 얼마인가?': '3층',
#  '1930년 회현동에 세워진 3층짜리 건물은 어떤 용도의 건물인가?': '공동주택',
#  '1935년 진보된 건축 기술로 내자동에 관사를 지은 회사의 이름은?': '경성 미쿠니상사',
#  '1935년 내자동에 지어진 관사는 벽돌대신 어떤 자재를 사용했나?': '콘크리트',
#  '1930년 주택을 3층으로 올린 공동주택이 세워진 곳은?': '회현동',
#  '1935년 경성 미쿠니상사는 어디에 관사를 지었나?': '내자동',
#  '유림아파트의 본래 이름은 무엇인가?': '풍전아파트',
#  '대한민국 첫 임대아파트이자 처음으로 아파트의 형식에 맞게 건설된 아파트의 이름은 무엇인가?': '충정아파트',
#  '1932년 우리나라에서 여러가지 주택 유형을 연구하며 다양한 대안을 실현한 단체의 이름은?': '조선주택영단',
#  '르꼬르 뷔제의 대안이기도 하며 산업혁명에서 양산화된 건축 양식은?': '아팔타멘토',
#  '대한민국의 첫 임대아파트는?': '충정아파트',
#  '대한민국 첫 임대아파트는?': '충정아파트',
#  '충정아파트의 초기 이름은?': '풍전아파트',
#  '청풍장 소화장아파트가 지어진 지역은?': '부산광역시',
#  '청풍장 소화장아파트가 1996년 안전진단에서 판정받은 등급은 무엇인가?': 'D등급',
#  '1941년과 1944년에 지어진 청풍장-소화장아파트는 어느 회사가 시공을 하였나?': '부산토지공사',
#  '청풍장-소화장아파트는 몇층 짜리 아파트인가?': '4층',
#  '청풍장-소화장 아파트는 초기에 아파트 외에 어떤 용도로 지어졌나?': '부산광역시청',
#  '1941년과 1944년 부산토지공사에서 지은 부산광역시 최초의 아파트는?': '청풍장-소화장아파트',
#  '청풍장-소화장아파트는 부산광역시에서 등록문화재 대신 무엇으로 지정되었는가?': '근대문화유산',
#  '이 아파트는 1961년 10월에 착공한 뒤 언제 완성이 되었나?': '1964년 11월 30일',
#  '본래 10층으로 건설할 계획이었으나 주변 기관의 반대로 몇 층으로 지어졌나?': '6층',
#  '1992년 재건축된 뒤 들어선 아파트는?': '마포 삼성아파트',
#  '국내 최초 중앙정원형 아파트이자 1965년 완공된 아파트의 이름은?': '동대문아파트',
#  '서울시가 동대문아파트와 함께 서울속 미래유산 1000선으로 선정하려고 했던 아파트의 이름은 무엇인가?': '충정아파트',
#  '1965년에 완공된 동대문아파트는 어떤 형태의 아파트인가?': '중앙정원형',
#  '동대문 아파트는 몇 층짜리 아파트인가?': '7층',
#  '동대문 아파트는 서울특별시에 현존하는 아파트 중에 몇 번째로 오래되었나?': '2번째',
#  '1965년 완공된 7층짜리 중앙정원형 아파트의 이름은?': '동대문아파트',
#  '동대문아파트는 서울시에서 미래유산 후보로 올린 뒤 무엇으로 선정되었나?': '미래유산 아파트',
#  '세계의 기운을 가진다는 뜻을 가진 상가의 이름은 무엇인가?': '세운상가',
#  '재력가나 정부 고위인사들이 거주하였고 당시 전자산업의 메카로 불렸던 구의 이름은 무엇인가?': '종로구',
#  '1967년에 지어진 세운상가를 설계한 사람은?': '김수근 건축가',
#  '세운상가는 어떤 용도의 건물인가?': '주상복합아파트',
#  '세운상가를 짓도록 주도하고 당시 불도저시장으로 불리던 시장의 이름은?': '김현옥',
#  '1967년 김현옥 시장이 주도하여 김수근 건축가가 설계한 최초의 주상복합아파트 이름은?': '세운상가',
#  '서울특별시에서 녹지사업의 일환으로 현대상가를 철거한 연도는?': '2008년',
#  '1967년 당시 선진 기술을 전수받기 위해 정부와 기업이 초청한 외국인들의 거주시설로 지어진 아파트의 이름은 무엇인가?': '힐탑아파트',
#  '힐탑아파트를 설계한 건축가의 이름은 무엇인가?': '안병의',
#  '1967년 정부와 기업이 초청한 외국인들의 거주시설 용도로 지어진 힐탑아파트가 지어진 장소는?': '용산구 한남동',
#  '대한주택공사가 힐탑아파트를 건설하기위해 일본 다이세이건설에서 빌린 것은 얼마어치 철근과 목재였나?': '100만 달러',
#  '힐탑아파트를 설계한 건축가의 이름은?': '안병의',
#  '1967년 우리 정부와 기업이 초청한 외국인들의 거주시설로 지어진 아파트 이름은?': '힐탑아파트',
#  '우리나라 첫 고층아파트라는 수식어를 지니고 있는 힐탑아파트는 총 몇 층이였나?': '11층',
#  '세대별로 온도조절이 가능한 난방 방식은 무엇인가?': '온수난방 방식',
#  '1994년 남산외인아파트가 철거 된 후 현재 그 자리에 조성된 것은 무엇인가?': '남산 야외식물원',
#  '1970년 착공한 남산외인아파트는 언제 완공됐나?': '1972년',
#  '남산외인아파트는 언제 철거됐나?': '1994년',
#  '현재 남산외인아파트 자리에는 무엇이 조성됐나?': '남산 야외식물원',
#  '1972년 완공하였으며 헬리포트 시설을 처음으로 설치한 아파트 이름은?': '남산외인아파트',
#  '1994년 남산외인아파트가 철거된 뒤 그 자리에 조성된 것은?': '남산 야외식물원',
#  '서울시에서 1969년 빈민주택의 불량함을 제거하고 환경파괴나 불법점거등의 주택단지를 없애기 위해 건립 추진한 아파트의 이름은 무엇인가?': '와우시민아파트',
#  '1970년 당시 서울 시장은 누구인가?': '김현옥',
#  '서울시가 건립을 추진한 와우시민아파트의 공사기간은?': '6개월',
#  '와우시민아파트 15동이 무너져서 사망한 주민의 수는?': '30명',
#  '와우시민아파트 붕괴 사고 한달 뒤 자리에서 물러난 서울시장의 이름은?': '김현옥',
#  '1969년 빈민주택의 불량함 제거, 환경파괴 등을 없애기 위해 서울시에서 대대적으로 건립을 추진했던 아파트 이름은?': '와우시민아파트',
#  '와우아파트의 부실 공사 때문에 사망한 주민 수는?': '30명',
#  '국내에서 마지막으로 지어진 시민아파트의 이름은 무엇인가?': '회현 제2 시민아파트',
#  '회현 제2 시민아파트는 누구를 위해 지어졌는가?': '철거민',
#  '회현 제2 시민아파트가 완공된 해는?': '1970년',
#  '박정희 정권의 계획하에 회현 제2시민아파트는 어떤 의도로 지어진 아파트인가?': '판자촌 정리 개발계획',
#  '회현 제2 시민아파트는 동대문아파트와 함께 무엇으로 지정되어 보존될 예정인가?': '서울미래유산후보',
#  '1970년 완공되어 국내에서 마지막으로 지은 시민아파트 이름은?': '회현 제2 시민아파트',
#  '회현 제2 시민아파트는 동대문아파트와 함께 어떤 별명으로 유명했나?': '연예인아파트',
#  '최초의 단지형 고층시범아파트이자 최초로 여의도에 지어진 건축물인 아파트의 이름은 무엇인가?': '여의도 시범아파트',
#  '여의도 시범아파트는 어떤 형식의 아파트인가?': '기둥식 아파트',
#  '여의도 시범아파트는 몇개의 세대로 구성되었나?': '1790세대',
#  '여의도 시범아파트는 몇 개의 동으로 구성되었나?': '24개동',
#  '여의도 시범아파트가 완공된 해는?': '1971년',
#  '1971년 여의도에 지어진 국내 첫 민간인 고층아파트의 이름은?': '여의도 시범아파트',
#  '여의도 시범 아파트는 총 몇 세대로 이루어져 있는가?': '1790세대',
#  '서소문 아파트는 어떤 형식의 아파트인가?': '선형식 아파트',
#  '서소문아파트가 지어진 연도는 언제인가?': '1971년',
#  '서소문 아파트가 지어진 해는?': '1971년',
#  '서소문 아파트는 하천을 따라 몇m 길이로 만들어졌나?': '115m',
#  '서소문 아파트가 철거될 때 주민들에게 주어지는 것은?': '임대아파트 입주권',
#  '1971년 지어져 1972년 입주했으며 서대문구 미근동에 위치한 선형식 아파트의 이름은?': '서소문 아파트',
#  '서소문 아파트의 건축을 담당한 업체 이름은?': '오진개발',
#  '초기 약현성당이 성도 들에게 아파트를 제공하기 위해 지어진 아파트의 이름은?': '성요셉 아파트',
#  '성요셉아파트가 서울시 미래유산 아파트로 선정된 이유는 무엇인가?': '특이한 건물형태',
#  '성요셉 아파트가 지어진 해는?': '1971년',
#  '성요셉 아파트는 몇 층으로 구성된 아파트인가?': '6층',
#  '1개 동으로 구성된 성요셉 아파트는 전면부에 입구가 몇개가 있나?': '3개',
#  '1971년 약현성당이 지었으며 서울시 중구 중림동에 위치한 아파트 이름은?': '성요셉 아파트',
#  '성요셉 아파트의 저층부 1개층은 무엇으로 이용되고 있는가?': '상가',
#  '1973년에 한국 최초로 건설된 주공아파트 대단지는 무엇인가?': '반포주공아파트',
#  '반포주공아파트가 국내 최초로 도입한 것은 무엇인가?': '복층 설계',
#  '한국 최초의 주공아파트 대단지인 반포주공아파트를 건설한 회사는?': '대한주택공사',
#  '반포주공아파트의 최대 평수는?': '62평',
#  '반포주공아파트는 몇가구로 구성되었나?': '3786가구',
#  '1973년 대한주택공사가 건설한 대한민국 최초의 대단지 주공아파트 이름은?': '반포주공아파트',
#  '반포주공아파트 철거 후 국내 최초의 주공아파트라는 점에서 서울시는 반포주공아파트 1개동을 무엇으로 조성할  계획인가?': '마을 박물관',
#  '전두화정권이 도입하였던 택지개발촉진법의 첫 사례이자 현대건설이 지은 주공아파트의 이름은?': '개포주공아파트',
#  '개포주공아파트가 재개발로 서울시와 갈등을 빚은 이유는?': '층수제한',
#  '개포주공아파트가 지어진 해는?': '1981년',
#  '개포주공아파트의 시공사는?': '현대건설',
#  '개포주공아파트는 몇 단지로 이루어져 있나?': '7단지',
#  '1981년 현대건설이 지은 주공아파트 이름은?': '개포주공아파트',
#  '개포주공아파트는 몇 개의 단지로 이루어져 있나?': '7단지',
#  '50가구 이상의 주택을 건설하는 사업자는 공개분양해야한다는 법은 무엇인가?': '주택건설촉진법',
#  '1976년 현대산업개발에서 건설하고 현재 국내에서 가장 비싼 아파트 가운데 하나인 아파트의 이름은 무엇인가?': '압구정 현대아파트',
#  '압구정 현대아파트를 건설한 회사는?': '현대산업개발',
#  '한남대교가 만들어진 해는?': '1969년',
#  '경부고속도로가 개통된 해는?': '1970년',
#  '1976년 현대산업개발에서 건설한 아파트단지 이름은?': '압구정 현대아파트',
#  '압구정 현대아파트가 한국에서 손꼽히는 고급 아파트 단지로 자리잡게 된 사건 이름은?': '특혜분양 사건',
#  '서울시가 근현대 문물 보존 프로젝트로 지정한 아파트는 몇군데인가?': '10군데',
#  '개포주공1단지아파트가 세워진 연도는?': '1981',
#  '2015년까지 100년 주택인 장수명 아파트 인증제 도입을 추진하는 기관은?': '국토교통부',
#  '서울시가 문물 보존 프로젝트로 미래문화유산화의 일부보존 대상으로 지정한 아파트의 수는?': '10',
#  '한국에서 가장 오래된 아파트는?': '충정아파트',
#  '고도의 성장으로 인해 40년 넘은 주택조차 찾기 어려움에 대한 조치 방법으로 국토교통부에서 추진하게 된 도입 방법은?': '장수명 아파트 인증제',
#  '서울시가 최근 미래문화유산화의 일부보존 대상 후보로 지정한 아파트는 총 몇 군데인가?': '10군데',
#  '물질적인 화폐가 아닌 가상화폐나 암호화폐 같은 것을 뜻하는 화폐를 무엇인가?': '디지털화폐',
#  '대한민국에서는 디지털화폐보다 좁은 개념으로 사용되는 화폐로 범용선 요건을 갖춰야 하는 화폐는 무엇인가?': '전자화폐',
#  '디지털방식으로만 사용될 수 있는 유형의 화폐는?': '디지털화폐',
#  '금전적 가치를 디지털정보로 바꾸고 암호화 한 것은?': '디지털화폐',
#  '대한민국의 경우 디지털화폐가 전자화폐가 되기 위해 갖추어야 할 요건은?': '범용성 요건',
#  '가상화폐와 암호화폐를 포괄하는 것은?': '디지털화폐',
#  '우리나라 전자화폐의 필요조건은?': '범용성',
#  '개발자가 발행하고 관리하는 화폐로 가상 회원들 사이에서만 사용되는 화폐는 무엇인가?': '가상화폐',
#  '가상화폐를 법화인 화폐인 경우도 있지만 진정한 화폐의 성질을 가지고 있지 않은 교환수단이라고 정의한 곳은?': '금융범죄규제망',
#  '2012년 가상화폐의 정의를 정의한 국제기구는?': '유럽중앙은행',
#  '개발자가 발행하고 관리하며 특정 가상 커뮤니티에서 통용되는 결제수단은?': '가상화폐',
#  '가상화폐라는 단어를 쓰지 못하는 비트코인, 이더리움 등을 일컫는 말은?': '암호화폐',
#  '가상화폐를 통제가 없는 디지털 화폐의 한 종류로 정의한 곳은?': '유럽중앙은행',
#  '가상화폐를 발행하고 관리하는 사람은?': '개발자',
#  '일정한 네트워크에서 화폐로 사용할 수 있으며 블록체인 기술을 이용한 화폐는 무엇인가?': '암호화폐',
#  '암호화폐는 금전적 가치가 디지털방식으로 표시되는데 이것을 인터넷상에서 운영,관리하는 방식은 무엇인가?': 'P2P 방식',
#  '암호화폐를 암호화하는 기술은?': '블록체인',
#  '암호화폐를 분산 저장하여 운영 관리 될 수 있도록 하는 인터넷상의 방식은?': 'P2P 방식',
#  '분산 거래장부로 기능하는 공적 테이터베이스는?': '블록체인',
#  '본래는 재화 교환의 매개체였으나 훗날 투자의 목적으로 변한 것은?': '암호화폐',
#  '암호화폐의 밑바탕이 되는 기술은?': '블록체인 기술',
#  '블록을 계속 연결하는 기법을 무엇인가?': '블록체인',
#  '블록체인은 양당사자 간의 거래를 영구적으로 증명하게 하기 위하여 무엇에 저항력을 가지고 있는가?': '데이터의 수정',
#  '암호화폐를 발행하고 관리하는 핵심 기법은?': '블록체인',
#  '블록을 잇따라 연결한 모음으로 정의되는 것은?': '블록체인',
#  '암호화폐 코인에 유효성을 부여하는 것은?': '블록체인',
#  '실물화폐와는 다르게 네트워크에 P2P방식으로 적장되는 것은?': '암호화폐',
#  '후속 블록의 개조를 통해서 데이터의 수정이 가능한것은?': '블록체인',
#  '소득세는 무슨 주의인가?': '열거주의',
#  '비트코인을 디지털화폐로 인정하고 제도권으로 끌어들여 나라의 수도를 디지털 금융의 중심지로 키우려고 하는 나라는 어디인가?': '영국',
#  '법인의 환 차익에 부과하는 세금은?': '법인세',
#  '비트코인을 디지털 화폐로 인정한 나라는?': '영국',
#  '열거주의적인 성격을 띄는 세금은?': '소득세',
#  '선진국과 달리 비트코인을 화폐로 허용한 나라는?': '영국',
#  '마이크로소프트 부사장의 이름은?': '제임스 알라드',
#  '워싱턴 주, 벨뷰에서 행사를 개최한 이유는?': '개발자 채용',
#  '마이크로소프트사는 개발자 채용을 위해 워싱턴 주 어디에서 행사를 개최하였는가?': '벨뷰',
#  '벨뷰에서 행사를 개최한 달에 마이크로소프트사에 입사한 전 세가 북미지사장이었던 사람은?': '피터 무어',
#  '2003년 8월 12일 새로운 콘솔 제품에 대한 그래픽 프로세서 공급 계약을 맺은 회사는?': 'ATI사',
#  '제논 소프트웨어 플랫폼에 대한 계획이 시작된 시기는?': '2003년 2월',
#  '마이크로소프트사가 개발자 채용을 위해 행사를 개최했던 곳은 워싱턴 주의 어디인가?': '벨뷰',
#  '2003년 2월에 마이크로소프트사에 입사한 전 세가 북미지사장은?': '피터 무어',
#  '엑스박스 360의 물품 중  별도로 판매되고 있는 것은?': '액세서리',
#  '무선 컨트롤러에 연결해 게임을 하면서 배터리를 충전할 수 있는 액세서리 이름은?': '플레이 앤 차지',
#  '엑스박스 360에서 레이싱 게임에 사용할 수 있는 액세서리는?': '무선 레이싱 휠',
#  '엑스박스 360에서 문자나 음성으로 채팅을 할 수 있는 기능은 무엇인가?': '엑스박스 라이브',
#  '업데이트하려면 여유 저장 공간이 얼마인가?': '128MB',
#  '새로운 업데이트를 발표한 날은?': '2008년 11월 19일',
#  '디스크에서 어디에 게임을 설치할 수 있는 기능을 가지고 있는가?': '하드 드라이브',
#  '이전 업데이트가 내장 메모리에 저장되었던 것과는 달리 이 업데이트는 최초로 무엇을 요구하는가?': '저장 장치',
#  '이 업데이트는 적어도 얼마만큼의 여유 공간이 있는 메모리 카드나 하드 드라이브가 있어야 하는가?': '128MB',
#  '엑스박스 기능 중 새 커뮤니티 시스템은 무엇을 생성 할 수 있나?': '디지털 아바타',
#  '새 커뮤니티 시스템의 업데이트는 언제 발표했나?': '2008년 11월 19일',
#  '마이크로소프트가 엑스박스 및 엑스박스 360 소유자에게 제공하는 온라인 서비스는?': '라이브 아케이드',
#  '플레이스테이션용으로 나온 라이브 아케이드에서 다른 콘솔로 출시된 게임 이름은?': '캐슬배니아',
#  '엑스박스 라이브 아케이드는 마이크로소프트가 엑스박스 및 엑스박스 360 소유자에게 제공하는 무슨 서비스인가?': '온라인 서비스',
#  '현재 이 온라인 서비스는 무엇과 통합되어 있는가?': '대시보드',
#  '라이브 아케이드에서 플레이스테이션용으로 나왔던 대표적인 게임은?': '밤의 교향곡',
#  '엑스박스 360용으로 개편된 시기는 언제인가?': '2005년 11월 22일',
#  '캐나다 태평양 철도 건설을 계기로 브리티시 컬럼비아가 연방에 가입한 연도는?': '1871년',
#  '1975년까지 캐나다에서 가장 크고 영향력 있었던 회사는?': '캐나다 태평양 철도회사',
#  '캐나다의 국가 상징 중 하나이며 근면성을 나타내는 동물은?': '비버',
#  '철도회사의 로고로 선택되었고 캐나다의 국가 상징중 하나인것은?': '비버',
#  '캐나다 대륙횡단철도가 현재 쓰이는 용도는?': '화물운송',
#  '철로는 동부 캐나다와 어느 지역 사이에 건설 되었는가?': '브리티시 컬럼비아',
#  '브리티시 컬럼비아가 연방에 가입한 시기는 언제인가?': '1871년',
#  '캐나다에서 1975년까지 가장 크고 영향력이 있는 회사는 무엇인가?': '캐나다 태평양 철도회사',
#  '대륙횡단 철도건설은 누구의 보수당이 시작한 사업이었는가?': '존 맥도날드',
#  '정부는 태평양과 동부의 여러 주를 잇는 철도를 1871년 7월 20일 이후 몇 년 안에 건설할 것을 제안했는가?': '10년',
#  '대륙횡단 철도건설은 캐나다 초대수상인 이 사람의 보수당이 시작한사업인데 누구인가?': '존 맥도날드',
#  '초기 캐나다의 존재는 대형사업이 중요했는데 대표적인 예는 무엇인가?': '대륙횡단철도건설',
#  '초기 캐나다에서 중요했던 대형사업은 무엇인가?': '대륙횡단철도건설',
#  '캐나다의 초대 수상은 누구인가?': '존 맥도날드',
#  '캐나다 초대수상인 존 맥도날드가 속해있는 정당은 무엇인가?': '보수당',
#  '존 맥도날드가 건설의 서쪽 종착점은 어디가 될 것이라고 했는가?': '포트하디',
#  '보수당이 1873년 물러간 이후 새로 집권한 수상은 누구인가?': '알렉산더 매캔지',
#  '태평양 스캔들로 보수당이 물러난 시기는 언제인가?': '1873년',
#  '보수당 대신 새로 집권한 자유당 출신의 수상은 누구인가?': '알렉산더 매캔지',
#  '선더베이와 위니펙 지역을 연결하는 철도는 언제 준공되었는가?': '1875년',
#  '사단장 대리로서 토텐코프를 지휘한 것은 누구인가?': '막스 지몬 SS준장',
#  '아이케 장군의 복귀를 단호히 거절한 것은 누구인가?': '하인리히 힘러',
#  '1941년 사단은 어디까지 진격했는가?': '데먄스크 근방',
#  '제2군은 1942년 1월 부터 언제까지 거의 고립된 상황이었는가?': '10월',
#  '1941년이 저물 무렵 제3SS기갑사단은 어디근방까지 진격하였나?': '데먄스크 근방',
#  '아이케 장군이 후방으로 전출된 후 토텐코프를 지휘한 사람은 누구인가?': '막스 지몬',
#  '아이케가 자신의 사단으로 복귀하는 것을 거절한 사람은 누구인가?': '하인리히 힘러',
#  '사단의 잔존병들이 재편성을 위해 이동한 곳은?': '프랑스',
#  '프랑스에 머물던 사단이 투입된 작전은?': '안톤 작전',
#  '사단은 무엇을 보충받아 제3SS기갑 척탄병 사단 토텐코프로 개편되었는가?': '기갑 연대',
#  '사단의 잔존병들은 언제 전선에서 철수하였는가?': '1942년 10월 말',
#  '아이케 장군이 지휘권을 다시 잡은 후 10월부터 다음해 2월까지 사단은 어디에 머물렀는가?': '프랑스',
#  '사단의 잔존병들이 프랑스로 이동한 년도는 언제인가?': '1942년',
#  '아이케 장군이 다시 지휘권을 받은 달은 언제인가?': '10월',
#  '전사한 아이케 장군의 뒤를 이어 사단장이 된 사람은?': '막스 지몬',
#  '사단이 이반코네프 상장의 공세를 저지하기 위해 참전한 전쟁은?': '제3차 하리코프 공방전',
#  '제3차 하리코프 공방전 당시 아이케 장군이 탑승한 관측기는?': '피젤러 슈토르히',
#  '4월 10일 지몬 장군을 대신해 사단장에 취임한 사람은 누구인가?': '헤르만 프리스 SS준장',
#  '아이케 장군이 전사한 때는 언제인가?': '제3차 하리코프 공방전',
#  '제3SS기갑사단이 이반 코네프 상장의 공세를 막기위해 참전한 전투는 무엇인가?': '제3차 하리코프 공방전',
#  '아이케가 사망한 후 아이케를 이어 제3SS기갑사단의 사단장이 된 사람은 누구인가?': '막스 지몬',
#  '박동원이 투수들의 부정적인 시선을 이겨내고 몇번 타자의 경험으로 잠재력을 터트렸는가?': '4번 타자',
#  '박동원이 정규 시즌 이후 활약한 대회는 무엇인가?': '플레이오프와 한국시리즈',
#  '박동원은 퓨처스 리그에서 몇번 타자로 활동했는가?': '4번',
#  '박동원 선수는 어떤 선수의 부진으로 선발로 출전하면서 기회를 잡았는가?': '허도환',
#  '2013 시즌 말에 부상으로 인해  뒤늦게 참여한 캠프는?': '일본 캠프',
#  '상무 야구단 시절 몇 번 타자였나?': '4번 타자',
#  '대통령이 임기 중에 레임덕에 빠지는 경우가 발생할 수 있는 정부형태는?': '대통령제',
#  '대통령의 임기 말, 원활한 국정 수행이 불가능한 상태를 무엇이라고 하는가?': '레임덕',
#  '대통령이 임기 중에 원할한 국정 수행을 하지 못하는 현상을 무엇이라 부르는가?': '레임덕',
#  '대통령의 원할한 국정수행이 불가능한 경우, 대통령을 대신하여 중립적인 성향의 국무총리가 국정을 주도하게 하는 내각을 무엇이라 하는가?': '거국내각',
#  '비상 시국에 의회의 모든 정당이 국가의 체제 존립을 위하여 내각에 참여할 때, 이때 세워지는 정부 내각을 무엇이라 하는가?': '거국일치내각',
#  '의회 총 선거로 가장 많은 의석을 획득한 정당이 정부 내각을 구성하는 정부형태는 무엇인가?': '의원내각제',
#  '의회 총선거를 통해 원내 의석의 다수당이 정부 내각을 구성하는 체제는?': '의원내각제',
#  '선거에서 과반을 차지한 정당이 없기때문에 의석 비중이 가장 큰 두세 정당이 공동 내각을 구성하는것을 무엇이라고 하는가?': '연립 내각',
#  '전쟁과 같은 비상사태에서 국가의 존립을 위해 모든 정당이 내각에 참여하는것을 무엇이라고 하는가?': '거국일치내각',
#  '의워내각제에서 의석 비중이 가장 큰 두세 정당이 공동으로 내각을 구성하는 것을 무엇이라 하는가?': '연립 내각',
#  '의원내각제에서 전쟁과 같은 비상 시국일 경우 의회의 모든 정당이 내각에 참여하는 형태를 무엇이라 하는가?': '거국일치내각',
#  "이승만의 총애를 받아 막강한 궈력으로 '부부통령'으로 불린 사람은?": '곽영주',
#  '곽영주는 이승만의 특명으로 오늘날의 경찰청급인 무엇에 임명되었나?': '경무관',
#  '일본군 하사관 출신인 송요찬이 대한민국에서 오른 지위는?': '육군참모총장',
#  '곽영주는 누구에게 발탁되어 경무대 경찰서에 배치되었는가?': '이승만',
#  '정치깡패이며 곽영주와 동향 출신이었던 인물은?': '이정재',
#  '곽영주는 누구의 도움으로 수도경찰학교에 입교했다는 설이 있었는가?': '이정재',
#  '곽영주는 이승만의 총애를 받으며 막강한 권력을 가져 어떤 별명을 얻게 되는가?': '부부통령',
#  '곽영주의 근무지가 경찰학교에서 경무대 경찰서로 바뀌게 된 해는?': '1948년',
#  '천안한 침몰 사건이 일어난 것은 언제인가?': '2010년 3월 26일',
#  '천안함 침몰 사건이 벌어진 곳은 어디인가?': '백령도 근처 해상',
#  '천안함 침몰 사건으로 사망한 대한민국 해군 장병은 몇 명인가?': '40명',
#  '천안함 피격 사건은 언제 일어났는가?': '2010년 3월 26일',
#  '천안함 피격 사건으로 사망한 해군 장병 수는?': '40명',
#  '조선민주주의인민공화국이 천안함을 공격했다는 조사결과에 반대한 두 나라는?': '중국과 러시아',
#  '천안한 침몰 사건의 지점에 배치한 해난구조함은?': '평택함',
#  '천안함 침몰 사건의 실종자 수색을 위해 배치한 함대는?': '광양함',
#  '침몰한 천안함의 탐색과 구조활동을 위해 현장 해역에 긴급 투입된 아시아 최대의 수송함은?': '독도함',
#  '대한민국 해군이 28일 실종자 수색을 위해 추가로 배치한 것은?': '광양함',
#  '아시아 최대의 수송함은?': '독도함',
#  '천안함 침몰 사건이 북한의 타격에 의한 것으로 볼 수 없다고 보도한 신문사는?': '한겨레 신문',
#  '조선민주주의인민공화국 소행이라는 결정적 증거로 한국 정부가 제시한 것은 무엇인가?': '1번 어뢰',
#  '대한민국 정부에만 천안함 침몰사건의 조사결과를 통보하지 않은 것은 어느나라인가?': '러시아',
#  '천안함 침몰이 조선민주주의인민공화국의 소행이라는 결정적 증거로 한국 정부가 제시한 것은?': '1번 어뢰',
#  '천안함 침몰 조사 결과를 대한민국 정부에만 통보하지 않아 대한민국 외교부가 항의한 나라는?': '러시아',
#  '러시아가 천안함 침몰 사건의 조사 결과를 통보한 나라는?': '미국과 중국',
#  '한국은 러지사의 천안함 침몰 사건 조사에 대한 요약본을 누구를 통해 전달받았다고 주장했는가?': '우방국',
#  '러시아측이 조사단의 요약보고서를 통보한 두 나라는?': '미국과 중국',
#  '한국은 어디를 통해 간접적으로 요약본을 전달받았다고 주장했는가?': '우방국',
#  '한국 정부가 러시아의 천안함 침몰 사건 조사에 비협조적으로 대응했다고 비판한 전 주한 미국 대사는?': '도널드 그레그',
#  '천안함 침몰 사건을 조사한 러시아 조사단은 몇 명인가?': '3명',
#  '요약본 전문에 명시된 바에 의하면, 천안함의 사고원인은?': '외부의 수중 폭발',
#  '전 주한 미국 대사의 이름은?': '도널드 그레그',
#  '한-러 간의 협력을 확인한 한-러 정상회담을 한 것은 언제인가?': '2010년 9월 15일',
#  '천안함 침몰 사건을 조사한 보고서를 어디에도 발표하지 않을 것이라고 한 러시아의 대통령은?': '드미트리 메드베데프',
#  '2010년 9월 15일 한-러 간의 협력을 확인한 모임은?': '한-러 정상회담',
#  '천안함 사건과 관련한 러시아 조사단의 보고서는 비밀문서이므로 한국이나 북한 어디에도 전달하지 않을 것이라고 말한 사람은?': '러시아 외무차관',
#  '한-러 정상회담시 UN에서 천안함 관련 논의에 있어서 러시아의 협력에 대해 사의를 표한 바 있다고 말한 우리나라 대통령은?': '이명박',
#  '북한의 박길연 외무성 부상은 어디에서 미국은 평화의 수호자가 아닌 파괴자라고 비판했는가?': '유엔 총회 연설',
#  '북한의 박길연 외무성 부상은 천안함 침몰 사건의 해결을 위해 무엇에 즉각 착수할 것을 요구했는가?': '남북대화',
#  '주러시아 북한 대사는 북한과 천안함 침몰사건은 무관하다며 기자회견을 연 곳은 어디인가?': '모스크바',
#  '유엔 총회 연설에서 천안함 사건을 이용해 미국과 남한이 무력 군사위협을 벌이고 있다고 비판한 인물은?': '박길연',
#  '박길연이 현안 해결을 위해 남한 정부에게 즉각 착수할 것을 요구하고 있는 것은?': '남북대화',
#  '천안함 침몰 사건의 원인으로 제기된 설은 무엇인가?': '북한 공격설과 사고설',
#  '천안함 침몰 사건의 원인중 내부충격에 의한 가설은 무엇인가?': '선내폭발설',
#  '천안함 침몰 사건의 원인으로 제기되는 가설 중 북한 공격설과 유실기뢰사고설, 좌초설은 무엇에 의한 것인가?': '외부충격',
#  '천안함 침몰 원인으로 크게 북한 공격설과 무엇을 들 수 있는가?': '사고설',
#  '천안함 침몰 원인에 대한 가설 중 내부 충격에 의한 것은?': '선내폭발설',
#  '4월 25일 합동조사단은 천안함 침몰 사건이 무엇때문에 일어났을 가능성이 높다고 발표했는가?': '비접촉 폭발',
#  '천안함 침몰 사고현장에서 수거한 파편에서 어떤 화약성분이 검출되었나?': 'RDX',
#  '김태영 국방장관이 천안함 침몰 사건의 원인이 어뢰 가능성이 높다고 답변한것은 어디인가?': '국회',
#  '천안함 사고 원인은 폭발에 의한 것으로 보인다고 국회에서 답변한 사람은?': '김태영 국방장관',
#  '2010년 4월 30일 사고현장에서 파편등을 검사한 결과 감출된 화약 성분은?': 'RDX',
#  '백령도 근해에 미처 제거하지 않은 기뢰에 의해 천안함이 침몰했다고 주장하는 가설은?': '기뢰사고설',
#  '한국군 기뢰는 현재 다 제거되었다며 천안함 침몰이 한국군이 설치한 기뢰에 의한 사고였을 가능성을 일축한 사람은?': '김태영 국방장관',
#  '천안함 사건이 폭발 가능성이나 좌초 가능성이 낮을 경우 가장 높은 개연성이 있는 침몰 원인은 무엇인가?': '피로파괴',
#  '천안함 침몰 사건의 원인이 선내결함이었을 가능성을 언급한 것은 누구인가?': '박선원 박사',
#  '천안함 선체 결함 가능성에 대해 부인한 천안함 함장은?': '최원일 중령',
#  '미세한 균열이 장시간 누적된 충격과 압력에 의해 갑작스런 파괴로 이어지는 현상을 무엇이라 하는가?': '피로 파괴',
#  '실종자 가족들이 제기한 선체결함 가능성에 대해 부인한 사람은?': '최원일 중령',
#  '침몰 요인으로 선내결함 가능성을 언급한 미국 브루킹스연구소 초빙연구원은?': '박선원 박사',
#  '고위급 탈북자는 천안함 침몰 사건이 북한이 몇년동안 철저히 준비해온 사건이라고 주장했는가?': '10년',
#  '고위급 탈북자는 연평해전의 피해로 사기가 떨어진 북한이 보복하기 위해 벌인 것이 무엇이라고 했는가?': '천안함 폭침',
#  '제2연평해전은 몇년도에 발생했는가?': '2002년',
#  '선체 프로펠러에서 나는 소음은 어느 정도 거리 이내에서 이뤄져야 감지되는가?': '10km 이내',
#  '천안함이 잠수함과 충돌해 침몰했을 가능성을 제기한 경성대 교수는 누구인가?': '김황수 교수',
#  '백령도에서 관측된 지진파의 주파수가 어떤 형태로 분석되었는가?': '조화 주파수',
#  '김황수 교수의 천안함과 잠수함의 충돌 주장에도 불구하고 충돌 흔적이 발견되지 않았다고 설명한 것은?': '국방부',
#  '김황수 교수와 코레스타 교수는 천안함 침몰 당시 백령도에서 관측된 무엇을 분석하여 잠수함 충돌 가능성을 제기했는가?': '지진파 주파수',
#  '수중 폭발에 의한 지진파에서는 어떤 형태의 지진파가 나타나지 않는가?': '조화 주파수',
#  '천안함 사건이 일어나기 직전 심상치 않은 움직임이 포착된 것은 무엇인가?': '북한 잠수정과 해안포',
#  '천안함 사건 당일 북한 해안포 10문이 모습을 드러냈음에도 어떠한 발령도 하지 않은 것을 문제삼은 국회의원은?': '신학용의원',
#  '천안함 사건 후 국방부장관을 해임하고 군법회의에 회부해야 한다고 주장한 것은 누구인가?': '민주당 박지원 원내대표',
#  '천안함 사건 직전에 심상치 않은 움직임이 있었는데도 전투태세 및 경계태세는 발령되지 않은 점을 문제삼은 사람은?': '민주당 신학용의원',
#  '실질적인 책임자인 국방부장관을 해임하고 군법회의에 회부해야 한다고 주장한 사람은?': '민주당 박지원 원내대표',
#  '천안함 사건 조사단의 구성원 문제나 은폐 가능성을 제기한 것은 누구인가?': '신상철',
#  '신상철은 천안함 사건이 누구와 연루되었다고 주장했는가?': '미군',
#  '천안함 사건의 조사를 위해 신상철을 추천한 것은?': '민주당',
#  '조사단의 구성원 문제나 은폐 가능성을 제기한 서프라이즈 대표는?': '신상철',
#  '신상철을 추천한 것에 대해 책임론이 제기된 당은?': '민주당',
#  '천안함 사태에 대해 문제를 제기한 도올 김용옥은 누구에게 고소를 당했는가?': '보수단체',
#  '천안함 사건으로 인해 국방부로부터 고소를 당한 것은 누구인가?': '박선원 전 청와대비서관',
#  '천안함 사태에 대해 문제를 제기해 고소, 고발을 당한 전 청와대 통일안보전략비서관은?': '박선원',
#  '천안함의 조사결과에  문제를 제기하는 사람들이 고소된 것은 우리 사회가 비합리적인 사회임을 보여주고 있다고 지적한 교수는?': '이승헌',
#  '천안함 침몰 사건에 대한 성금 모금이 진행된 것은 언제인가?': '2010년 4월 14일',
#  '천안함 침몰 사건을 패전이라 지적한 것은 누구인가?': '도올 김용옥',
#  '천안함 사건의 희생자들에게 정부가 공식적으로 사용하고 있는 호칭은?': '용사',
#  '국방부는 천안함 희생자들에게 무엇을 수여했는가?': '훈장',
#  '58명을 구조한 공을 인정해줘야 한다는 견해가 나오고 있는 사람은?': '최원일 함장',
#  '천안함 침몰 사건에 대해 북한의 책임론을 주장한 당은?': '한나라당',
#  '합동조사단의 천안함 사고 조사 발표날짜는 원래 언제였는가?': '5월 23일',
#  '천안함 침몰 사건에 대해 정치권의 대립되는 책임론은 무엇의 우위를 점하기 위한 전략이었는가?': '지방선거',
#  '천안함 침몰 사건에 대해 북한의 책임론을 주장하고 있는 당은?': '한나라당',
#  '천안함 사건이 조선민주주의인민공화국의 공격에 의한 것일 경우 어떠한 사람들을 결집시켜 선거의 지지율을 상승하게 만드는가?': '보수주의자들',
#  '천안함 사건에 대한 정부의 발표를 신뢰한다는 의견이 높은 지역은?': '대구, 경북지역',
#  '천안함 사건에 대해 북한의 소행이라는 답변이 많았던 연령층은?': '50대 이상',
#  '어떤 당의 지지자들이 천안함 사건에 대한 정부의 발표를 신뢰한다는 답변이 많았는가?': '한나라당',
#  '5월 30일 여론조사에서 정부의 조사를 신뢰한다는 응답은 몇 퍼센트였는가?': '64%',
#  '9월 14일 실시된 여론조사에서 정부의 발표에 대해 신뢰도가 높은 지역은?': '대구, 경북지역',
#  '천안함 사건 민,군 합동조사단장은 누구인가?': '윤덕용',
#  '천안함 사건의 조사에 대해 날조된 것이라 주장한 북한 유엔대표는?': '신선호',
#  '천안함 사건에 대한 한국의 브리핑은 철저한 조사, 북한의 브리핑은 주장이라고 말한 토마스 마이르 -하팅은 어느나라의 대사인가?': '오스트리아',
#  '천안함 사건 민군 합동조사단장은?': '윤덕용',
#  '한국의 브리핑은 철저한 조사인 반면, 북한의 브리핑은 주장이라고 말한 오스트리아 대사는?': '토마스 마이르-하팅',
#  '천안함 침몰 사건의 조사결과에 대한 의문점을 담은 서한을 안전보장이사회에 보낸 것은 누구인가?': '참여연대',
#  '몇 명의 법률가가 참여연대에 대한 검찰의 수사를 중단하라는 시국선언을 발표했는가?': '342명',
#  '시민단체가 유엔에 이견을 제시한 것은 한국 민주주의의 성숙성을 보여준다고 평가한 존스홉킨스대 교수는?': '서재정',
#  '천안함 사건의 조사결과에 대한 의문점을 담은 서한을 안보리와 이사국들에 보낸 시민단체는?': '참여연대',
#  '아시아인권위는 참여연대에 대한 한국정부와 보수단체의 옭죄기를 막아달라는 서한을 누구에게 보냈는가?': '반기문 UN 사무총장',
#  '천안함 침몰 사건으로 군의 대응실태를 조사한 감사원은 몇 명에 대해 징계를 요청했는가?': '25명',
#  '감사원의 대규모 징계 요청에 반대한 것은 누구인가?': '김태영 국방부장관',
#  '천안함 침몰 사건으로 군의 대응실태를 조사한 감사원의 감사 결과가 발표된 후 몇 명을 입건했는가?': '4명',
#  '이번 사건에서 군의 대응 실태를 조사한 기관은?': '감사원',
#  '감사원의 감사 결과가 발표된 이후 3개월이 넘도록 몇 명 입건하는데 그쳤는가?': '4명',
#  '김현웅은 사법연수원 몇기인가?': '16기',
#  '김현웅은  서울고등검찰청 검사장으로 재직하고 있을때 어떤 장관으로 임용되었는가?': '법무부 장관',
#  '1959년 5월 4일에 태어난 대한민국 법률가의 이름은?': '김현웅',
#  '김현웅은 서울고등검찰청 검사장 재직 중에 몇대 법무부 장관에 임용되었나?': '제64대',
#  '김현웅 전 법무부 장관에게 변호사 개업을 자제할 것을 권고한 것은?': '대한변호사협회',
#  '사상 최초로 전직 고등법원 부장판사급 법관 A씨에게 알선수재 혐의의 사전 구속영장을 청구한 검사는?': '김현웅',
#  '제46대 서울고등검찰청 검사장 재직 중 제 64대 법무부장관에 임용된 대한민국의 법률가는?': '김현웅',
#  '안무가 로빈 안틴이 크리스티나 애플게이트, 카마 칼라와 함께 구상한 클럽 공연단은 언제 처음으로 공연 하였는가?': '1995년',
#  '로빈 안틴이 구상한 클럽 공연단은 1999년 6월 어느 잡지에 세미누드 사진으로 실렸는가?': '플레이보이',
#  '로빈 안틴이 구상한 현대적인 클럽 공연단이 처음으로 공연을 한 해는?': '1995년',
#  '공연단의 몇몇 멤버들이 핑크 팬더의 테마에 맞춰 춤을 추는 모습으로 출연한 영화의 이름은?': '미녀 삼총사 2',
#  '2002년 푸시캣 돌스에 대한 대중의 관심을 높인 화보를 찍은 곳은?': '맥심 지',
#  '2003년 푸시캣 돌스의 리드보컬로 영입된 사람은 누구인가?': '니콜 셰르징거',
#  "푸시캣 돌스가 영화 '쉘 위 댄스'의 사운드 트랙에 곡을 싣은 것 중, 어떤 곡이 그룹의 첫 싱글로 발매 되었는가?": 'Sway',
#  '니콜 셰르징거는 무엇을 위해 인터스코프 레코드를 찾았다가 푸시캣 돌시에 영입 되었는가?': '솔로 레코딩 계약',
#  '2003년 푸시캣 돌스의 리드보컬로 영입된 인물은?': '니콜 셰르징거',
#  '셰르징거가 찾아왔다가 우연히 푸시캣 돌스에 영입된 곳은?': '인터스코프 레코드',
#  '그루의 첫 싱글로 발매된 곡을 OST로 쓴 영화의 제목은?': '쉘 위 댄스',
#  '푸시캣 돌스의 첫 번째 정규 음반 PCD는 언제 발매 되었는가?': '2005년 9월 13일',
#  "푸시캣 돌시의 첫 싱글 'Don't Cha'는 빌보드 핫 100위 차트에서 몇 위를 차지 했는가?": '2위',
#  "'Don't Cha'는 한국 휴대전화 기기 제조사의 휴대전화 CM송으로도 사용되었는데 그 제조사는 어디인가?": 'SKY',
#  '푸시캣 돌스의 첫 정규 음반이 발매된 해는?': '2005년',
#  '푸시캣 돌스의 첫 정규 음반이 전세계에서 팔린 갯수는?': '900만 장',
#  'SKY가 휴대전화 CM에서 푸시캣 돌스의 노래와 함꼐 춘 춤은?': '맷돌춤',
#  '푸시캣 돌스의 노래 중 미국에서 5위에 오른 두번 째 싱글의 제목은 무엇인가?': 'Stickwitu',
#  '푸시캣 돌스의 여섯번 째 싱글은 누가 피쳐링 하였는가?': 'Timbaland',
#  "푸시캣 돌스의 네번 째 상글 'Buttons'는 누구와 작업을 한 곡인가?": 'Snoop Dogg',
#  '두 번째 싱글인 Stickwitu가 5위에 오른 나라는?': '미국',
#  '푸시캣 돌스의 여섯번째 싱글을 피처랑한 사람은?': 'Timbaland',
#  '푸시캣 돌스의 여섯번째 싱글이 미국 차트에서 차지한 순위는?': '40위',
#  '푸시캣 돌스의 리얼리티 TV 프로그램의 방영일자는 언제 였는가?': '2007년 3월 6일',
#  '푸시캣 돌스의 리얼리티 TV 프로그램에서 뽑힌 새 멤버의 이름은 무엇인가?': '아시아 니톨라노',
#  '푸시캣 돌스의 자체 리얼리티 TV 프로그램이 찾으려고 한 것은?': '새 멤버',
#  '리얼리티 프로그램으로 뽑힌 푸시캣 돌스의 새 멤버가 함께 진행할 예정이었던 것은?': '투어',
#  '푸시캣 돌스의 자체 리얼리티 TV 프로그램의 최종 우승자 이름은?': '아시아 니톨라노',
#  '2008년 8월 탈퇴한 푸시캣돌스의 멤버는 누구인가?': '카밋 버쳐',
#  '2008년 5월 27일 발매한 푸시캣 돌스의 새 싱글은?': 'When I Grow Up',
#  '푸시캣 돌스의 네 번째 싱글은 어느 지역에만 한정으로 발매되었는가?': '미국과 오세아니아',
#  '카밋 버쳐가 탈퇴한 해는?': '2008년',
#  '2008년 푸시캣 돌스의 When I Grow Up이 핫 댄스 클럽 플레이 차트에서 차지한 등수는?': '1위',
#  '미국과 오세아니아 지역 한정으로 발매된 푸시캣 돌스의 네 번째 싱글의 제목은?': 'Bottle Pop',
#  '푸시캣 돌스의 월드 투어 중 니요가 지원해준 투어 지역은 어디인가?': '영국',
#  '푸시캣 돌스의 서울 첫 내한공연 날은 언제인가?': '2009년 6월 6일',
#  '푸시캣 돌스의 월드 투어에서 유럽과 오스트레일리아 공연에서 지원해준 가수는 누구인가?': '레이디 가가',
#  '푸시캣 돌스가 앨범 홍보를 위해 나선 월드 투어의 이름은?': 'Doll Domination Tour',
#  '푸시캣 돌스가 월드 투어를 할 때 유럽과 오스트레일리아 공연에서 오프닝을 맡은 사람은?': '레이디 가가',
#  '2009년 부상으로 내한공연에 불참하여 한국에 오지 못한 멤버는?': '제시카 수타',
#  '푸시캣 돌스가 영국에서 발매한 Doll Domination: The Mini Collection 은 언제 발매 되었는가?': '2009년 4월 27일',
#  "'Jai Ho!'는 어떤 영화의 오리지널 사운드트랙인가?": '슬럼독 밀리어네어',
#  '셰르징거가 앨범을 재발매할 것이라고 한 곳은?': '빌보드 지',
#  '유럽과 영국 지역에 한해서 발매한 것은?': '재발매반',
#  '영화 슬럼독 밀리어네어의 오리지널 사운드트랙에서 따온 싱글 곡의 이름은?': 'Jai Ho!',
#  "제시카 수타는 그룹에서 '쫓겨났다'고 폭로한 곳은 어디인가?": 'E!Online',
#  '2월 26일 Loaded Magazine은 누가 푸시캣 돌스를 떠났다는 사실을 확인했다고 보도하였는가?': '킴벌리 와이어트',
#  '2010년 제시카 수타가 갈비뼈 부상 이후 그룹에서 쫒겨났다고 폭로한 곳은?': 'E!Online',
#  '자신의 홈페이지를 통해 그룹 탈퇴 소식을 알린 사람은?': '애슐리 로버츠',
#  '니콜 셰르징거가 공식적으로 그룹 탈퇴를 선언한 해는?': '2010년',
#  'Entertainment Weekly의 마고 왓슨은 푸시캣돌스의 어떤 인물의 지나친 부각을 강하게 비판하였는가?': '리드보컬 니콜 셰르징거',
#  '푸시캣 돌스의 니콜 셰르징거의 지나친 부각을 비판한 인물은 Entertainment Weely의 누구인가?': '마고 왓슨',
#  '니콜 셰르징거에 대한 지나친 부각을 비판한 사람은?': '마고 왓슨',
#  '푸시캣 돌스의 2005년 히트 앨범은?': 'PCD',
#  '히트 앨범 PCD가  세간에 부각시킨 인물은?': '니콜 셰르징거',
#  'Electric Sound Product는 언제 설립되었나?': '1975년',
#  'ESP가 미국에 리페어샵을 지은 때는?': '1981년 3월',
#  '2002년 ESP가 음악산업에서 가장 빠르게 성장하는 회사로 등극하게 된 이유는?': '펜더사가 Jackson Guitars를 인수',
#  'ESP는 최초 설립 당시 어떤 목표를 가진 회사였는가?': '최고급 전기 기타의 제조와 전문 리페어 샵',
#  'ESP가 미국 뉴욕에 처음 리페어샵을 설립한 연도는?': '1981년',
#  'ESP는 무엇의 약자인가?': 'Electric Sound Product',
#  '최고 품질의 기타를 만들어 주문제작을 해준 ESP 설립자는 누구인가?': '시부야 히사타케',
#  '1993년 EPS 본사를 이전한 지역은 어디인가?': '로스 앤젤레스',
#  'ESP에 많은 기타의 종류는?': '시그네처 기타',
#  'ESP의 첫 시그네처 기타는 어떤 사람의 기타인가?': '조지 린치',
#  'ESP가 정식 엔도서로 활동중인 그룹의 이름은?': 'Metallica',
#  'ESP의 첫 시그네처 기타는?': '조지 린치의 ESP Kamikaze',
#  '1989년에 발매된 메탈리카의 기타리스트 커크 헤밋의 시그네처 기타의 이름은?': 'ESP KH-2',
#  'ESP는 무엇이 가장 많은 브랜드로 알려져있나?': '시그네처 기타',
#  '커크 해밋은 어느 그룹 소속의 기타리스트인가?': '메탈리카',
#  'ESP는 무엇을 전문으로 제작하는가?': '커스텀 악기',
#  '2014년 2월부터 ESP 대신에 달고 있는 로고는 무엇인가?': 'E-II',
#  '미국과 유럽 등 에서 주로 팔리는 수출형 ESP 모델은 어떤 것인가?': 'Standard 시리즈',
#  'ESP의 Standard series는 몇%의 수제작 공정과 몇%의 자동화 공정을 통해 만들어 지는가?': '70%의 수제작 공정과 30%의 자동화 공정',
#  'ESP의 Standard series는 몇년도에 단종되었는가?': '2014년',
#  'ESP에서 2014년 단종된 Standard Series의 명맥을 이어 제작되고 있는 모델은?': 'E-II',
#  '2009년 새 공장은 어디에 건립 되었는가?': '사이타마',
#  'ESP측의 정책 변경으로 2014년에 단종된 것은?': 'Standard Series',
#  'Standard 시리즈는 무슨 시리즈와 동일하게 만든것인가?': 'Original',
#  '승리의 본명은?': '이승현',
#  '승리의 고향은 어디인가?': '광주광역시',
#  '승리가 나온 초등학교 이름은?': '정암초등학교',
#  '가수 승리가 천곡중학교 시절 멤버로 활동했던 댄스 그룹은?': '일화',
#  '2005년 승리가 지원한 오디션 프로그램인 레츠 코크플레이 배틀신화를 방영한 곳은?': 'Mnet',
#  'YG 엔터테인먼트에서 만든 최초의 아이돌 힙합그룹으로 승리가 멤버로 합류한 그룹은?': 'BIGBANG',
#  '가수 승리의 본명은?': '이승현',
#  '승리가 천곡중학교 시절 활동하였던 댄스 그룹의 이름은 무엇인가?': '일화',
#  '승리는 빅뱅의 멤버가 될 수 있는 마지막 오디션 기회에서 타샤니의 어떤 곡을 불렀는가?': '하루하루',
#  '빅뱅에 첫 싱글은 언제발매했는가?': '2006년 8월 19일',
#  '빅뱅에 데뷔 앨범 이름은?': 'Bigbang',
#  '빅뱅에 데뷔 일자는?': '2006년 9월 23일',
#  '2006년 빅뱅이 발표한 첫 싱글은?': 'Bigbang',
#  '빅뱅이 음악프로그램 쇼 음악중심에 공식 데뷔한 해는?': '2006년',
#  '2006년 빅뱅의 첫 정규 음반에 수록된 승리의 첫 솔로 곡은?': '다음 날',
#  '빅뱅의 첫 싱글이 발매된 날짜는?': '2006년 8월 19일',
#  '빅뱅의 첫 싱글 앨범의 이름은?': 'Bigbang',
#  '빅뱅의 첫 번째 EP인 Always의 타이틀 곡 제목은 무엇인가?': '거짓말',
#  '승리에 뮤지컬 첫작품 이름은?': '소나기',
#  '승리가 음악 프로그램MC는 멤버 누구랑 했는가?': '대성',
#  '승리에 영화 데뷔작은?': '우리 집에 왜 왔니',
#  '승리가 뮤지컬 배우로 첫 도전한 작품은?': '소나기',
#  '승리가 뮤지컬 샤우티에 함께 출연할 예정이었으나 교통사고로 출연이 무산된 빅뱅 멤버는?': '대성',
#  '2009년 승리의 영화 데뷔작은?': '우리 집에 왜 왔니',
#  '빅뱅 멤버 중 가장 먼저 뮤지컬에 출연한 이는 누구인간?': '승리',
#  '승리는 2009년 어떤 작품으로 영화에 데뷔하였나?': '우리 집에 왜 왔니',
#  ...}

# %%
# 학습 데이터셋.
count = 100
train_prompt_list = []
for idx, (question, answer) in enumerate(refined_dict.items()):
    if idx >= count:
        break

    prompt = f"<s>### Instruction: {question} ### Response: {answer}</s>"
    train_prompt_list.append({"text": prompt})

# %%
type(train_prompt_list), len(train_prompt_list)
train_prompt_list[:3]
# Out:
# [{'text': '<s>### Instruction: 임종석이 여의도 농민 폭력 시위를 주도한 혐의로 지명수배 된 날은? ### Response: 1989년 2월 15일</s>'},
#  {'text': '<s>### Instruction: 1989년 6월 30일 평양축전에 대표로 파견 된 인물은? ### Response: 임수경</s>'},
#  {'text': '<s>### Instruction: 임종석이 여의도 농민 폭력 시위를 주도한 혐의로 지명수배된 연도는? ### Response: 1989년</s>'}]

# %%
train_dataset = Dataset.from_list(train_prompt_list)
train_dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 100
# })

# %%
train_dataset[-1]
# Out:
# {'text': '<s>### Instruction: 미야코 만 해전에서 아쓰오카 바키치 함장이 폭풍우를 만난 년도는? ### Response: 1869년</s>'}

# %%
import torch
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments
)
from trl import SFTTrainer      # LLM 학습(파인튜닝)을 위한 Trainer
from peft import LoraConfig     # LoRA 설정

import os

# %%
model_name = "TinyPixel/Llama-2-7B-bf16-sharded"

# %%
load_in_4bit = True
bnb_4bit_compute_dtype = torch.float32
bnb_4bit_quant_type = "nf4"
bnb_4bit_use_double_quant = False

bnb_config = BitsAndBytesConfig(
    load_in_4bit=load_in_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=bnb_4bit_compute_dtype,
    bnb_4bit_use_double_quant=bnb_4bit_use_double_quant,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 load_in_4bit = True
# ----> 2 bnb_4bit_compute_dtype = torch.float32
#       3 bnb_4bit_quant_type = "nf4"
#       4 bnb_4bit_use_double_quant = False
#
# NameError: name 'torch' is not defined

# %%
# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="auto"
)
model.config.use_cache = False
model.config.pretraining_tp = 1  # 병렬 처리를 단일 처리에 맞게 설정

# %%
# tokenizer loading
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token  # padding 토큰과 eos 토큰을 같게 처리
tokenizer.padding_side = "right" # padding을 오른쪽(뒤에) 붙이도록 설정

# %%
output_dir = "./results"  # 모델 저장할 경로로
num_train_epochs = 40     # 에폭수

# bf16 = True             # 처리할 때 사용할 타입을 bf16

per_device_train_batch_size = 16 # batch size
per_device_eval_batch_size = 16

learning_rate = 2e-4
weight_decay = 0.001  # step 마다 lr을 줄여나가는 크기.

optim = "paged_adamw_32bit" # 옵티마저 - adam의 변형.

lr_scheduler_type = "constant"
warmup_ratio = 0.03    # 주기적으로 lr을 줄였다가 다시 키우는 것을 lr warmup 고한다. 키우는 비율

save_steps = 25        # 몇 스텝마다 저장할지
logging_steps = 25     # 몇 스텝마다 로그를 남길지.

# %%
# Set training parameters
hub_model_name = 'kgmyh/llama-2-ko-7b-korquad'
api_key = "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"
# https://huggingface.co/

training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    # bf16=bf16,
    warmup_ratio=warmup_ratio,
    lr_scheduler_type=lr_scheduler_type,
    report_to="none",

    push_to_hub=True,          
    hub_model_id=hub_model_name,  
    hub_token=api_key,            
)

# %%
lora_r = 64         # adapter 행렬 : 입력 d X r(64)  r(64) X d
lora_alpha = 16     # model의 layer의 출력결과와 adapter의 출력결과를 줄때 adpater쪽의 가중치 결정하는 값
                    # r 보다 크면 adapter 가중치를 더 크게. r보다 작으면 layer의 출력결과의 가중치를 더크게
                    # adapter 출력 * (alapha / r)
lora_dropout = 0.1

# LoRA 설정
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)

# %%
max_seq_length = 256 

# Trainer 생성
trainer = SFTTrainer(
    model=model,
    processing_class=tokenizer,
    train_dataset=train_dataset,  
    args=training_arguments,      
    peft_config=peft_config,      
)

# %%
# 학습
from warnings import filterwarnings
filterwarnings(action='ignore')


trainer.train()

# %%
import huggingface_hub

huggingface_hub.login(api_key) # HF 로그인
tokenizer.push_to_hub(hub_model_name) # 모델 학습할 때 사용한 토크나이저 업로드.

# %% [markdown]
# # 추론
#
# ##  Merge
# - base model과 Lora 모델을 합쳐서 사용한다.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from peft import PeftModel
import torch


model_name = "TinyPixel/Llama-2-7B-bf16-sharded"
hub_model_name = 'kgmyh/llama-2-ko-7b-korquad'

# %%
base_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map="auto",
)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

# %%
# base model에 lora 어뎁터를 합친다.(merge)
load_model = PeftModel.from_pretrained(base_model, hub_model_name) # base모델, adapter load
load_model = load_model.merge_and_unload() # 합친다.

# %%
def predict(query:str, pipeline)->str:
    prompt = f"<s>###Instruction: {query} ###Response: "
    result = pipeline(prompt)
    return result

# %%
lora_pipeline = pipeline(
    "text-generation",
    model=load_model, 
    device_map="auto", 
    tokenizer=tokenizer, 
    max_length=256, # 출력  max Length
    truncation=True)


query = "임종석이 여의도 농민 폭력 시위를 주도한 혐의로 지명수배 된 날은?"
query = "헤이그가 군에서 퇴역한 년도는 몇년도입니까?"
predict(query, lora_pipeline)

# %%
train_dataset[0]
# Out:
# {'text': '<s>### Instruction: 임종석이 여의도 농민 폭력 시위를 주도한 혐의로 지명수배 된 날은? ### Response: 1989년 2월 15일</s>'}

# %%
list(train_dataset)
# Out:
# [{'text': '<s>### Instruction: 임종석이 여의도 농민 폭력 시위를 주도한 혐의로 지명수배 된 날은? ### Response: 1989년 2월 15일</s>'},
#  {'text': '<s>### Instruction: 1989년 6월 30일 평양축전에 대표로 파견 된 인물은? ### Response: 임수경</s>'},
#  {'text': '<s>### Instruction: 임종석이 여의도 농민 폭력 시위를 주도한 혐의로 지명수배된 연도는? ### Response: 1989년</s>'},
#  {'text': '<s>### Instruction: 임종석을 검거한 장소는 경희대 내 어디인가? ### Response: 학생회관 건물 계단</s>'},
#  {'text': '<s>### Instruction: 임종석이 조사를 받은 뒤 인계된 곳은 어딘가? ### Response: 서울지방경찰청 공안분실</s>'},
#  {'text': '<s>### Instruction: 1989년 2월 15일 여의도 농민 폭력 시위를 주도한 혐의로 지명수배된 사람의 이름은? ### Response: 임종석</s>'},
#  {'text': '<s>### Instruction: 임종석이 1989년 2월 15일에 지명수배 받은 혐의는 어떤 시위를 주도했다는 것인가? ### Response: 여의도 농민 폭력 시위</s>'},
#  {'text': '<s>### Instruction: 정부의 헌법개정안 준비 과정에 대해서 청와대 비서실이 아니라 국무회의 중심으로 이뤄졌어야 했다고 지적한 원로 헌법학자는? ### Response: 허영</s>'},
#  {'text': "<s>### Instruction: '행보가 비서 본연의 역할을 벗어난다', '장관들과 내각이 소외되고 대통령비서실의 권한이 너무 크다'는 의견이 제기된 대표적인 예는? ### Response: 10차 개헌안 발표</s>"},
#  {'text': '<s>### Instruction: 국무회의의 심의를 거쳐야 한다는 헌법 제 몇 조의 내용인가? ### Response: 제89조</s>'},
#  {'text': '<s>### Instruction: 법무부 장관을 제쳐놓고 민정수석이 개정안을 설명하는 게 이해가 안 된다고 지적한 경희대 석좌교수 이름은? ### Response: 허영</s>'},
#  {'text': '<s>### Instruction: 미국 군대 내 두번째로 높은 직위는 무엇인가? ### Response: 미국 육군 부참모 총장</s>'},
#  {'text': '<s>### Instruction: 로널드 레이건 정부 출범 당시 알렉산더 헤이그는 어떤 직책을 맡았는가? ### Response: 초대 국무장관직</s>'},
#  {'text': '<s>### Instruction: 알렉산더 헤이그는 어느 대통령의 밑에서 국무장관을 지냈는가? ### Response: 로널드 레이건 대통령</s>'},
#  {'text': '<s>### Instruction: 로널드 레이건 대통령 밑에서 일한 국무 장관은 누구인가? ### Response: 알렉산더 메이그스 헤이그 2세</s>'},
#  {'text': '<s>### Instruction: 미국 군대에서 두번째로 높은 직위는? ### Response: 미국 육군 부참모 총장</s>'},
#  {'text': '<s>### Instruction: 알렉산더 메이그스 헤이그의 생년월일은? ### Response: 1924년 12월 2일</s>'},
#  {'text': '<s>### Instruction: 알렉산더 헤이그가 로널드 레이건 대통령 밑에서 맡은 직책은 무엇이었나? ### Response: 국무장관</s>'},
#  {'text': '<s>### Instruction: 알렉산더 헤이그가 1984년 발간한 회고록의 제목은 무엇인가? ### Response: 경고:현실주의, 레이건과 외교 정책</s>'},
#  {'text': '<s>### Instruction: 알렉산더 헤이그와 1950년 5월 결혼한 상대의 이름은 무엇인가? ### Response: 퍼트리샤 앤토이넷 폭스</s>'},
#  {'text': '<s>### Instruction: 알렉산더 헤이그가 미국 육군사관학교로 임명받은 해는 언제인가? ### Response: 1944년</s>'},
#  {'text': '<s>### Instruction: 알렉산더 헤이그는 퍼트리샤 앤토이넷 폭스와 결혼해 몇 명의 자녀를 두었는가? ### Response: 3명</s>'},
#  {'text': '<s>### Instruction: 헤이그가 공부한 대학교는? ### Response: 노터데임 대학교</s>'},
#  {'text': '<s>### Instruction: 헤이그의 부인은 누구인가? ### Response: 퍼트리샤 앤토이넷 폭스</s>'},
#  {'text': '<s>### Instruction: 알렉산더 헤이그가 나온 대학교는? ### Response: 노터데임 대학교</s>'},
#  {'text': '<s>### Instruction: 육군사관학교에서 졸업한 헤이그가 제일 처음 소위로 발령받은 부대는 무엇이었나? ### Response: 정통 제병 연합부대</s>'},
#  {'text': '<s>### Instruction: 1950년 헤이그와 결혼한 여자의 이름은? ### Response: 퍼트리샤 앤토이넷 폭스</s>'},
#  {'text': '<s>### Instruction: 헤이그가 군에서 퇴역한 해는 언제인가? ### Response: 1979년</s>'},
#  {'text': '<s>### Instruction: 알렉산더 헤이그를 사성 장군과 육군 부참모로 진급시킨 대통령은 누구인가? ### Response: 닉슨 대통령</s>'},
#  {'text': '<s>### Instruction: 헤이그는 나토에서 얼마나 있었습니까? ### Response: 5년</s>'},
#  {'text': '<s>### Instruction: 헤이그가 군에서 퇴역한 년도는 몇년도입니까? ### Response: 1979년</s>'},
#  {'text': '<s>### Instruction: 제럴드 포드 대통령 시기 헤이그가 최고사령부의 최고 사령관으로 임명된 곳은 어디인가? ### Response: 미국 유럽 연합군</s>'},
#  {'text': '<s>### Instruction: 헤이그가 군대에서 퇴역한 년도는? ### Response: 1979년</s>'},
#  {'text': '<s>### Instruction: 퇴역 후 헤이그는 어느 회사의 대표가 되었나? ### Response: 미국 기술 주식 회사</s>'},
#  {'text': '<s>### Instruction: 알렉산더 헤이그는 레이건의 조언자들을 무엇이라고 묘사하였는가? ### Response: 외교 정책의 아마추어</s>'},
#  {'text': '<s>### Instruction: 헤이그가 사적생활을 하다가 정계로 돌아갔던 해는 언제인가? ### Response: 1988년</s>'},
#  {'text': '<s>### Instruction: 헤이그를 기용한 국제적 상담 회사의 이름은 무엇입니까? ### Response: Worldwide Associates Inc</s>'},
#  {'text': '<s>### Instruction: 헤이그가 정계로 돌아간 년도는 몇년도입니까? ### Response: 1988년</s>'},
#  {'text': '<s>### Instruction: 레이건 대통령의 조언자들을 헤이그는 무엇이라고 묘사하였나? ### Response: 외교 정책의 아마추어</s>'},
#  {'text': '<s>### Instruction: 헤이그가 정계로 다시 돌아간 년도는? ### Response: 1988년</s>'},
#  {'text': '<s>### Instruction: 하나님의 명령에 배를 만들고 가족과 짐승들을 배에 태워 홍수를 피한 사람은 누구인가? ### Response: 노아</s>'},
#  {'text': '<s>### Instruction: 노아의 방주에 대해 기록하고있는 복음서는 무엇인가? ### Response: 창세기</s>'},
#  {'text': '<s>### Instruction: 노아의 방주의 선체는 어떠한 나무로 만들었는가? ### Response: 고페르나무</s>'},
#  {'text': '<s>### Instruction: 노아는 누구의 명령에 따라 배를 만들고 가족과 동물들을 태웠는가? ### Response: 하나님</s>'},
#  {'text': '<s>### Instruction: 노아의 방주는 몇층으로 구성되어 있었는가? ### Response: 3층</s>'},
#  {'text': '<s>### Instruction: 노아의 방주에 안쪽에 발라 굳힌 것은? ### Response: 역청</s>'},
#  {'text': '<s>### Instruction: 1규빗을 미터법으로 환산하면 얼마인가? ### Response: 45~46cm</s>'},
#  {'text': '<s>### Instruction: 노아의 방주는 총 몇층으로 되어 있었는가? ### Response: 3층</s>'},
#  {'text': '<s>### Instruction: 노아의 방주를 만든 재질은? ### Response: 고페르나무(잣나무)</s>'},
#  {'text': '<s>### Instruction: 노아의 방주를 상징적 의미로 받아들이는 종교는 무엇인가? ### Response: 기독교</s>'},
#  {'text': '<s>### Instruction: 노아의 방주의 실존에 대한 의문이 제기되고 세계적 홍수가 없었다는 것이 밝혀지게된 이유는? ### Response: 역사학과 과학의 발달</s>'},
#  {'text': '<s>### Instruction: 역사학과 과학의 발달이 미비했을 때 전통 신학계에서는 어떠한 시작으로 노아의 방주를 역사적 사실로 기술하였는가? ### Response: 근본주의적</s>'},
#  {'text': '<s>### Instruction: 전통 신학계의 근본주의적 시작을 여전히 받아들여 노아의 방주를 역사적 사실로 인식하는 집단은? ### Response: 보수적 근본주의계열의 개신교</s>'},
#  {'text': '<s>### Instruction: 현대 대부분의 기독교에서는 노아의 방주를 어떤 의미로 받아들이는가? ### Response: 상징적 의미</s>'},
#  {'text': '<s>### Instruction: 현재도 노아의 방주를 역사적 사실로 받아들이는 집단은? ### Response: 보수적 근본주의계열의 개신교</s>'},
#  {'text': '<s>### Instruction: 노아의 방주의 실존에 대한 의문을 제기한 학문은? ### Response: 역사학과 과학</s>'},
#  {'text': '<s>### Instruction: 제칠일안식교에서 비롯된 의사과학의 한 종류인 유사지질학의 이름은 무엇인가? ### Response: 홍수지질학</s>'},
#  {'text': '<s>### Instruction: 극보수주의계열의 기독교이자 아직도 노아의 홍수가 있었다고 주장하는 곳은 어디인가? ### Response: 남침례교</s>'},
#  {'text': '<s>### Instruction: 고대사회에서 성경은 교리를 다루는 책일 뿐만 아니라 어떤 책으로도 권위가 상당했는가? ### Response: 역사책</s>'},
#  {'text': '<s>### Instruction: 역사학과 과학의 발달로 홍수지질학은 어떤 과학으로 남게 되었는가? ### Response: 유사과학</s>'},
#  {'text': '<s>### Instruction: 현대에 노아의 방주에 대학 근본주의적 해석은 어떻게 여겨지는가? ### Response: 비과학적인 해석</s>'},
#  {'text': '<s>### Instruction: 유사지질학인 홍수지질학이 근원은? ### Response: 제칠일안식교</s>'},
#  {'text': '<s>### Instruction: 유사지질학자들이 노아의 홍수를 증명하기 위해 성경 이외에 근거라고 주장한 것들은? ### Response: 이슬람교 경전이나 길가메쉬 서사시</s>'},
#  {'text': '<s>### Instruction: 노아의 방주가 역사적으로 실재했다는 주장은 무엇이 존재하지 않아 학계로부터 전혀 인정받지 못하고 있는가? ### Response: 증거</s>'},
#  {'text': '<s>### Instruction: 한국에서 홍수지질학적 주장들을 내어 놓고 있는 집단은? ### Response: 한국창조과학회</s>'},
#  {'text': '<s>### Instruction: 1955년 목재의 파편을 발견한 프랑스의 탐험가 이름은? ### Response: Fernand Navarra</s>'},
#  {'text': '<s>### Instruction: 2012년 중국에서 노아의 방주가 발견되었다는 보도를 한 방송사는 어디인가? ### Response: BTV</s>'},
#  {'text': '<s>### Instruction: 노아의 방주는 무엇으로 만들었기 때문에 현재까지 남아 있는 것이 불가능한가? ### Response: 목재</s>'},
#  {'text': '<s>### Instruction: 중국에서 2012년 발견되었다고 주장한 노아의 방주는 화석화가 진행되지 않은 무엇때문에 가짜임이 밝혀졌는가? ### Response: 나무</s>'},
#  {'text': '<s>### Instruction: 1955년 프랑스 탐험가가 발견한 목재파편은 스페인 연구소에서 몇 년 전 것이라고 밝혀졌는가? ### Response: 5000년 전</s>'},
#  {'text': '<s>### Instruction: 2012년 중국 BTV에서 노아의 방주가 발견되었다고 보도한 나라는? ### Response: 중국</s>'},
#  {'text': '<s>### Instruction: 현재의 생물다양성은 대략 몇 종 인가? ### Response: 870만</s>'},
#  {'text': '<s>### Instruction: 노아의 홍수가 실재한다면 진화적 종분화가 얼마 만에 이루어져야하는가? ### Response: 3-4천년</s>'},
#  {'text': '<s>### Instruction: 급작스러운 폭우로 담수와 염수가 섞일 경우 삼투압 변화로 폐사하는 생물류는? ### Response: 수생생물</s>'},
#  {'text': '<s>### Instruction: 가지고 있는 특성이 없어지는 것은 진화가 아니라는 창조과학회의 주장의 예시는? ### Response: 북극곰</s>'},
#  {'text': '<s>### Instruction: 만약 대홍수가 실재했다면 현생 지구의 생물다양성에 이르기 위해서는 종분화가 몇년 이내에 이루어졌어야 하는가? ### Response: 3-4천년</s>'},
#  {'text': '<s>### Instruction: 담수와 염수가 급작스럽게 섞일 경우 대부분의 수생생물이 폐사하는 원인은? ### Response: 급격한 삼투압 변화</s>'},
#  {'text': '<s>### Instruction: 노아 가족과 동물들이 노아의 방주에서 버틴 날짜는 총 몇일인가? ### Response: 375일</s>'},
#  {'text': '<s>### Instruction: 목재 선박의 배수량의 한계는 얼마인가? ### Response: 2000톤</s>'},
#  {'text': '<s>### Instruction: 노아의 방주가 안정적인 구조였다고 주장하는 집단은 어디인가? ### Response: 창조과학회</s>'},
#  {'text': '<s>### Instruction: 목재 선박은 강도상의 문제로 통상 길이 몇m가 한계인가? ### Response: 100m</s>'},
#  {'text': '<s>### Instruction: 노아의 방주 안정성을 실험하기 위한 연구가 있다고 주장하는 단체는? ### Response: 창조과학회</s>'},
#  {'text': '<s>### Instruction: 노아의 방주 안전성을 연구하는 주요 연구자의 직업은? ### Response: 초등학교 교사</s>'},
#  {'text': '<s>### Instruction: 목재로 만들어진 선박은 강도 상의 통상 길이 몇m가 한계인가? ### Response: 100m</s>'},
#  {'text': '<s>### Instruction: 목재 선박의 배수량 한계는? ### Response: 2000톤</s>'},
#  {'text': '<s>### Instruction: 1868년 게이오 4년 4월 11일 반류마루는 누구에게 양도되기로 약속되었는가? ### Response: 신정부 군</s>'},
#  {'text': '<s>### Instruction: 1868년 게이오 4년 4월 11일 신정부 군에게 양도되기로 한 반류마루를 기상 불량 등의 이유로 연기한 후 인도를 거부한 사람은 누구인가? ### Response: 에노모토 다케아키</s>'},
#  {'text': '<s>### Instruction: 1868년 게이오 4년 8월 19일 자정 반류마루가 탈출한 해역은 어디인가? ### Response: 시나가와</s>'},
#  {'text': '<s>### Instruction: 막부 해군이 정박하고 있던 시나가와 해역을 탈출한 시간은? ### Response: 자정</s>'},
#  {'text': '<s>### Instruction: 군함에 통합되어 실제로 쇼군이 엠퍼러에 첫 좌승한것은 대정봉환 이후 어디에 이송되었을 때인가? ### Response: 슨푸 번</s>'},
#  {'text': '<s>### Instruction: 1868년 당시 일본의 해군 부총재는? ### Response: 에노모토 다케아키</s>'},
#  {'text': '<s>### Instruction: 에노모토 해군인 반류마루가 주력함이 되었던 전쟁은? ### Response: 하코다테 전쟁</s>'},
#  {'text': '<s>### Instruction: 쇼군이 반류마루에 좌승한 것은? ### Response: 슨푸 번에 이송되었을 때</s>'},
#  {'text': '<s>### Instruction: 하코다테 전쟁 시 반류마루의 함장의 이름은 무엇인가? ### Response: 마쓰오카 바키치</s>'},
#  {'text': '<s>### Instruction: 반류마루가 미야코 만 해전에서 폭풍우를 만나 대기하고 있던 항구의 이름은 무엇인가? ### Response: 하치노헤</s>'},
#  {'text': '<s>### Instruction: 반류마루가 미야코 만 해전당시 폭풍우를 만나 요함과 헤어졌을 때에 만날 약속하여 하치노헤 항에서 대기한 날짜는 언제인가? ### Response: 1869년 메이지 2년 3월 25일</s>'},
#  {'text': '<s>### Instruction: 함장 마쓰오카 바키치는 배를 조정하는 명수로 로프 하나 손상되지 않았다고 말한 사람은? ### Response: 하야시 다다스</s>'},
#  {'text': '<s>### Instruction: 철갑선의 사정거리에 들어간 순간에 순풍이 불기 시작하여 추격을 뿌리치고 어디로 돌아올 수 있었는가? ### Response: 하코다테</s>'},
#  {'text': '<s>### Instruction: 마쓰오카 바키치함장의 능력과 지휘과 기록된 기록되어 남은 전쟁은? ### Response: 하코다테 전쟁</s>'},
#  {'text': '<s>### Instruction: 미야코 만 해전에서 아쓰오카 바키치 함장이 폭풍우를 만난 년도는? ### Response: 1869년</s>'}]
